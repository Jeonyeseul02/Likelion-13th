# %%
import folium

# %%
# 나의 맛집리스트 
loc = folium.Map(location = [35.81837240599993, 127.14587868657603 ], zoom_start=15)

folium.Marker([35.81541193965123, 127.1398860821358 ], popup='전주 온담', icon = folium.Icon(color = 'purple', icon='info-sign')).add_to(loc)
folium.Marker([35.820346371620495, 127.13988863986019 ], popup='전주 리가든', icon = folium.Icon(color = 'purple', icon='info-sign')).add_to(loc)
folium.Marker([35.83983622329842, 127.12368813986063 ], popup='전주 온담', icon = folium.Icon(color = 'purple', icon='info-sign')).add_to(loc)
folium.Marker([35.81833967535993, 127.13885676869499 ], popup='전주 이치아더포라이프', icon = folium.Icon(color = 'purple', icon='info-sign')).add_to(loc)
folium.Marker([35.841851124029624, 127.12697765335568 ], popup='전주 구디', icon = folium.Icon(color = 'purple', icon='info-sign')).add_to(loc)


loc.save("myfoodlist.html")

loc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
#내가 자주가는 곳 
loc = folium.Map(location = [35.85331138082669, 127.12018702932177 ], zoom_start=12)

folium.Marker([35.851746098456736, 127.12119553981262], popup='빈타이', icon = folium.Icon(color = 'purple', icon='info-sign')).add_to(loc)
folium.Marker([35.85485208284857, 127.11898259753104 ], popup='할리스', icon = folium.Icon(color = 'purple', icon='info-sign')).add_to(loc)
folium.Marker([35.81860627474629, 127.13978143985999 ], popup='프랭크커핀바', icon = folium.Icon(color = 'purple', icon='info-sign')).add_to(loc)
folium.Marker([35.8194803734238, 127.14266779753014 ], popup='마래당', icon = folium.Icon(color = 'purple', icon='info-sign')).add_to(loc)
folium.Marker([35.8440203157731, 127.12802192174573 ], popup='청년다방', icon = folium.Icon(color = 'purple', icon='info-sign')).add_to(loc)


loc.save("jeonju_list.html")

loc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...
