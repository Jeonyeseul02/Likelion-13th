# %%
myfood = ['banana','apple','candy']
print(myfood[0])
print(myfood[1])
print(myfood[2])
# Out:
# banana
# apple
# candy

# %%
for item in myfood:
    print(item)
# Out:
# banana
# apple
# candy

# %%
dict1 = { 'one':'하나', 'two':'둘', 'three':'셋'  }
dict2 = { 1:'하나', 2:'둘', 3:'셋' }
dict3 = { 'col1':[1,2,3], 'col2':['a', 'b', 'c']  }

# %%
print(dict1)
print(dict2)
print(dict3)
# Out:
# {'one': '하나', 'two': '둘', 'three': '셋'}
# {1: '하나', 2: '둘', 3: '셋'}
# {'col1': [1, 2, 3], 'col2': ['a', 'b', 'c']}

# %%
import pandas as pd

# %%
from pandas import Series, DataFrame
import matplotlib as mpl

# %%
print("pandas 버전 :", pd.__version__)
print("matplotlib:", mpl.__version__)
# Out:
# pandas 버전 : 1.2.4
# matplotlib: 3.3.4

# %%
from pandas import Series, DataFrame

# %%
score = Series([1000,14000,3000,3000,1000])
print(score)
# Out:
# 0     1000
# 1    14000
# 2     3000
# 3     3000
# 4     1000
# dtype: int64

# %%
type(score)
# Out:
# pandas.core.series.Series

# %%
print(score.index)
print(score.values)
print(list(score.index))

print(type(score.index))
print(type(list(score.index)))
print(type(score.values))
# Out:
# RangeIndex(start=0, stop=5, step=1)
# [ 1000 14000  3000  3000  1000]
# [0, 1, 2, 3, 4]
# <class 'pandas.core.indexes.range.RangeIndex'>
# <class 'list'>
# <class 'numpy.ndarray'>

# %%
score = Series(['a','b','c'])
score
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
score_idx = Series(['a','b','c'],index = ['2021-09-16','2021-09-17','2021-09-18'])
score_idx
# Out:
# 2021-09-16    a
# 2021-09-17    b
# 2021-09-18    c
# dtype: object

# %%
for idx in score.index:
    print(idx)
# Out:
# 0
# 1
# 2

# %%
for value in score.values:
    print(value)
# Out:
# a
# b
# c

# %%
idx = pd.date_range(start ="2020-01-01", end="2020-02-02").tolist()
idx
# Out:
# [Timestamp('2020-01-01 00:00:00', freq='D'),
#  Timestamp('2020-01-02 00:00:00', freq='D'),
#  Timestamp('2020-01-03 00:00:00', freq='D'),
#  Timestamp('2020-01-04 00:00:00', freq='D'),
#  Timestamp('2020-01-05 00:00:00', freq='D'),
#  Timestamp('2020-01-06 00:00:00', freq='D'),
#  Timestamp('2020-01-07 00:00:00', freq='D'),
#  Timestamp('2020-01-08 00:00:00', freq='D'),
#  Timestamp('2020-01-09 00:00:00', freq='D'),
#  Timestamp('2020-01-10 00:00:00', freq='D'),
#  Timestamp('2020-01-11 00:00:00', freq='D'),
#  Timestamp('2020-01-12 00:00:00', freq='D'),
#  Timestamp('2020-01-13 00:00:00', freq='D'),
#  Timestamp('2020-01-14 00:00:00', freq='D'),
#  Timestamp('2020-01-15 00:00:00', freq='D'),
#  Timestamp('2020-01-16 00:00:00', freq='D'),
#  Timestamp('2020-01-17 00:00:00', freq='D'),
#  Timestamp('2020-01-18 00:00:00', freq='D'),
#  Timestamp('2020-01-19 00:00:00', freq='D'),
#  Timestamp('2020-01-20 00:00:00', freq='D'),
#  Timestamp('2020-01-21 00:00:00', freq='D'),
#  Timestamp('2020-01-22 00:00:00', freq='D'),
#  Timestamp('2020-01-23 00:00:00', freq='D'),
#  Timestamp('2020-01-24 00:00:00', freq='D'),
#  Timestamp('2020-01-25 00:00:00', freq='D'),
#  Timestamp('2020-01-26 00:00:00', freq='D'),
#  Timestamp('2020-01-27 00:00:00', freq='D'),
#  Timestamp('2020-01-28 00:00:00', freq='D'),
#  Timestamp('2020-01-29 00:00:00', freq='D'),
#  Timestamp('2020-01-30 00:00:00', freq='D'),
#  Timestamp('2020-01-31 00:00:00', freq='D'),
#  Timestamp('2020-02-01 00:00:00', freq='D'),
#  Timestamp('2020-02-02 00:00:00', freq='D')]

# %%
idx = pd.date_range(start="2020-01-01",end="2020-01-03").tolist()

score_idx = Series( ['a', 'b', 'c'], 
                   index=idx )
score_idx
# Out:
# 2020-01-01    a
# 2020-01-02    b
# 2020-01-03    c
# dtype: object

# %%
gildong = Series([1500,3000,2500], index=['2019-05-01','2019-05-02','2019-05-03'])
toto = Series([3000,3000,2000], index =['2019-05-01','2019-05-03','2019-05-02'])

# %%
gildong + toto
# Out:
# 2019-05-01    4500
# 2019-05-02    5000
# 2019-05-03    5500
# dtype: int64

# %%
idx1 = pd.date_range(start="2020-01-01",end="2020-01-03").tolist()
idx2 = pd.date_range(start="2020-02-01",end="2020-02-03").tolist()

gildong = Series( [1500,3000,2500],index = idx1)

toto = Series( [3000,3000,2000],index = idx2)

# %%
gildong
# Out:
# 2020-01-01    1500
# 2020-01-02    3000
# 2020-01-03    2500
# dtype: int64

# %%
toto
# Out:
# 2020-02-01    3000
# 2020-02-02    3000
# 2020-02-03    2000
# dtype: int64

# %%
from pandas import DataFrame

# %%
dat = {'col1':[1,2,3,4],'col2':[10,20,30,40],'col3':['A','B','C','D']}

df = DataFrame(dat)
df
# Out:
#    col1  col2 col3
# 0     1    10    A
# 1     2    20    B
# 2     3    30    C
# 3     4    40    D

# %%
dat = {'like_foods':['크로플','떡볶이','삼겹살'],'hate_foods':['닭발','마라탕','곱창']}
df = DataFrame(dat)
df
# Out:
#   like_foods hate_foods
# 0        크로플         닭발
# 1        떡볶이        마라탕
# 2        삼겹살         곱창

# %%
idx_date = pd.date_range(start="2020-01-01",end="2020-01-03").tolist()

# %%
from pandas import DataFrame

team_score = { "toto":[1500,3000,5000,7000,5500],
               "apple":[4000,5000,6000,5500,4500],
               "gildong":[2000,2500,3000,4000,3000],
               "catanddog":[7000,5000,3000,5000,4000]}

team_df = DataFrame(team_score)
team_df
# Out:
#    toto  apple  gildong  catanddog
# 0  1500   4000     2000       7000
# 1  3000   5000     2500       5000
# 2  5000   6000     3000       3000
# 3  7000   5500     4000       5000
# 4  5500   4500     3000       4000

# %%
team_df['toto']
# Out:
# 0    1500
# 1    3000
# 2    5000
# 3    7000
# 4    5500
# Name: toto, dtype: int64

# %%
# 두 개의 열 선택
sel = ['catanddog','toto']
team_df[sel]
# Out:
#    catanddog  toto
# 0       7000  1500
# 1       5000  3000
# 2       3000  5000
# 3       5000  7000
# 4       4000  5500

# %%
# 잘 못 된 예시
##   team_df = ['catanddog','toto']
# 해결 예시
## team_df = [['catanddog','toto']]

# %%
team_df
# Out:
#    toto  apple  gildong  catanddog
# 0  1500   4000     2000       7000
# 1  3000   5000     2500       5000
# 2  5000   6000     3000       3000
# 3  7000   5500     4000       5000
# 4  5500   4500     3000       4000

# %%
#team_df.loc[행선택, 열선택]
team_df.loc[0:2, 'apple':'gildong']
# Out:
#    apple  gildong
# 0   4000     2000
# 1   5000     2500
# 2   6000     3000

# %%
team_df.loc[:, ['gildong']]
# Out:
#    gildong
# 0     2000
# 1     2500
# 2     3000
# 3     4000
# 4     3000

# %%
team_df.loc[:, 'apple':'gildong']
# Out:
#    apple  gildong
# 0   4000     2000
# 1   5000     2500
# 2   6000     3000
# 3   5500     4000
# 4   4500     3000

# %%
team_df.loc[1:3, 'toto':'gildong']
# Out:
#    toto  apple  gildong
# 1  3000   5000     2500
# 2  5000   6000     3000
# 3  7000   5500     4000

# %%
team_df.loc[[1,3], :]
# Out:
#    toto  apple  gildong  catanddog
# 1  3000   5000     2500       5000
# 3  7000   5500     4000       5000

# %%
team_df.loc[:, ['apple','catanddog']]
# Out:
#    apple  catanddog
# 0   4000       7000
# 1   5000       5000
# 2   6000       3000
# 3   5500       5000
# 4   4500       4000

# %%
#team_df.loc[:, ['apple','catanddog']]
team_df[ ['apple','catanddog']] #loc가 빠지고 뒤에 : 이 사라지면 열선택
# Out:
#    apple  catanddog
# 0   4000       7000
# 1   5000       5000
# 2   6000       3000
# 3   5500       5000
# 4   4500       4000

# %%
team_df.loc[ [1,3], ['apple','catanddog']]
# Out:
#    apple  catanddog
# 1   5000       5000
# 3   5500       5000

# %%
team_df.loc[ 2:3, 'apple':'catanddog']
# Out:
#    apple  gildong  catanddog
# 2   6000     3000       3000
# 3   5500     4000       5000

# %%
team_df.loc[ 2:3, 'apple':]
# Out:
#    apple  gildong  catanddog
# 2   6000     3000       3000
# 3   5500     4000       5000

# %%
team_df.iloc[:,:]
# Out:
#    toto  apple  gildong  catanddog
# 0  1500   4000     2000       7000
# 1  3000   5000     2500       5000
# 2  5000   6000     3000       3000
# 3  7000   5500     4000       5000
# 4  5500   4500     3000       4000

# %%
team_df.iloc[[0],:]
# Out:
#    toto  apple  gildong  catanddog
# 0  1500   4000     2000       7000

# %%
team_df.iloc[0:2,0:2]
# Out:
#    toto  apple
# 0  1500   4000
# 1  3000   5000

# %%
team_df.iloc[[2,4],:]
# Out:
#    toto  apple  gildong  catanddog
# 2  5000   6000     3000       3000
# 4  5500   4500     3000       4000

# %%
team_df.iloc[1:5,1:3]
# Out:
#    apple  gildong
# 1   5000     2500
# 2   6000     3000
# 3   5500     4000
# 4   4500     3000

# %%
team_df.iloc[1:3,0:2]
# Out:
#    toto  apple
# 1  3000   5000
# 2  5000   6000

# %%
team_df.iloc[1:3,[1,3]]
# Out:
#    apple  catanddog
# 1   5000       5000
# 2   6000       3000

# %%
team_df.iloc[1:3,1:4:2]
# Out:
#    apple  catanddog
# 1   5000       5000
# 2   6000       3000

# %%
idx_date = pd.date_range(start="2020-01-01",end="2020-01-05").tolist()
team_df.index = idx_date
team_df
# Out:
#             toto  apple  gildong  catanddog
# 2020-01-01  1500   4000     2000       7000
# 2020-01-02  3000   5000     2500       5000
# 2020-01-03  5000   6000     3000       3000
# 2020-01-04  7000   5500     4000       5000
# 2020-01-05  5500   4500     3000       4000

# %%
idx_date = pd.date_range(start="2019-05-01",end="2019-05-05").tolist()
team_df.index = idx_date
team_df
# Out:
#             toto  apple  gildong  catanddog
# 2019-05-01  1500   4000     2000       7000
# 2019-05-02  3000   5000     2500       5000
# 2019-05-03  5000   6000     3000       3000
# 2019-05-04  7000   5500     4000       5000
# 2019-05-05  5500   4500     3000       4000

# %%
print(team_df.loc[ '2019-05-02' ] ) # 19-05-02 일
print("-----------")
print(team_df.loc[ ['2019-05-02', '2019-05-03'] ]) # 5월 2일, 3일 
print("-----------")
print(team_df.loc[ '2019-05-02': ])  # 5월 2일 이후 전체 데이터 가져오기
# Out:
# toto         3000
# apple        5000
# gildong      2500
# catanddog    5000
# Name: 2019-05-02 00:00:00, dtype: int64
# -----------
#             toto  apple  gildong  catanddog
# 2019-05-02  3000   5000     2500       5000
# 2019-05-03  5000   6000     3000       3000
# -----------
#             toto  apple  gildong  catanddog
# 2019-05-02  3000   5000     2500       5000
# 2019-05-03  5000   6000     3000       3000
# 2019-05-04  7000   5500     4000       5000
# 2019-05-05  5500   4500     3000       4000

# %%
## 컬럼명 확인 
print(team_df.columns)
print("-----")
print(team_df.loc[:, 'toto'])   # 전체행, toto팀 
print("-----")
print(team_df.loc[:, ['toto', 'gildong'] ])   # 전체행, toto, gildong팀
print("-----")
print(team_df.loc[:, 'toto': ])   # 전체행, toto 부터 끝까지
# Out:
# Index(['toto', 'apple', 'gildong', 'catanddog'], dtype='object')
# -----
# 2019-05-01    1500
# 2019-05-02    3000
# 2019-05-03    5000
# 2019-05-04    7000
# 2019-05-05    5500
# Name: toto, dtype: int64
# -----
#             toto  gildong
# 2019-05-01  1500     2000
# 2019-05-02  3000     2500
# 2019-05-03  5000     3000
# 2019-05-04  7000     4000
# 2019-05-05  5500     3000
# -----
#             toto  apple  gildong  catanddog
# 2019-05-01  1500   4000     2000       7000
# 2019-05-02  3000   5000     2500       5000
# 2019-05-03  5000   6000     3000       3000
# 2019-05-04  7000   5500     4000       5000
# 2019-05-05  5500   4500     3000       4000

# %%
print(team_df.iloc[0])      # 첫번째 행 접근
print("------")
print(team_df.iloc[ [0,1] ])  # 첫번째 두번째 행 접근
print("------")
print(team_df.iloc[ 0:3:1] )  # 첫번째부터 세번째 행 접근
print("------")
range_num = list(range(0,3,1))
print(team_df.iloc[ range_num ] )  # 첫번째부터 세번째 행 접근
# Out:
# toto         1500
# apple        4000
# gildong      2000
# catanddog    7000
# Name: 2019-05-01 00:00:00, dtype: int64
# ------
#             toto  apple  gildong  catanddog
# 2019-05-01  1500   4000     2000       7000
# 2019-05-02  3000   5000     2500       5000
# ------
#             toto  apple  gildong  catanddog
# 2019-05-01  1500   4000     2000       7000
# 2019-05-02  3000   5000     2500       5000
# 2019-05-03  5000   6000     3000       3000
# ------
#             toto  apple  gildong  catanddog
# 2019-05-01  1500   4000     2000       7000
# 2019-05-02  3000   5000     2500       5000
# 2019-05-03  5000   6000     3000       3000

# %%
print(team_df.iloc[0])
print(type(team_df.iloc[0]))
# Out:
# toto         1500
# apple        4000
# gildong      2000
# catanddog    7000
# Name: 2019-05-01 00:00:00, dtype: int64
# <class 'pandas.core.series.Series'>

# %%
team_df.sum()
# Out:
# toto         22000
# apple        25000
# gildong      14500
# catanddog    24000
# dtype: int64

# %%
team_df.sum(axis=1) #index별 합 : 0 , column별 합 : (1)
# Out:
# 2019-05-01    14500
# 2019-05-02    15500
# 2019-05-03    17000
# 2019-05-04    21500
# 2019-05-05    17000
# dtype: int64

# %%
team_df.mean()
# Out:
# toto         4400.0
# apple        5000.0
# gildong      2900.0
# catanddog    4800.0
# dtype: float64

# %%
team_df.std()
# Out:
# toto         2162.174831
# apple         790.569415
# gildong       741.619849
# catanddog    1483.239697
# dtype: float64

# %%
#표준편차, 분산, 최댓값, 최솟값
print( team_df.std(), end='\n\n')
print( team_df.var(), end='\n\n')
print( team_df.max(), end='\n\n')
print( team_df.min(), end='\n\n')
# Out:
# toto         2162.174831
# apple         790.569415
# gildong       741.619849
# catanddog    1483.239697
# dtype: float64
#
# toto         4675000.0
# apple         625000.0
# gildong       550000.0
# catanddog    2200000.0
# dtype: float64
#
# toto         7000
# apple        6000
# gildong      4000
# catanddog    7000
# dtype: int64
#
# toto         1500
# apple        4000
# gildong      2000
# catanddog    3000
# dtype: int64

# %%
team_df
# Out:
#             toto  apple  gildong  catanddog
# 2019-05-01  1500   4000     2000       7000
# 2019-05-02  3000   5000     2500       5000
# 2019-05-03  5000   6000     3000       3000
# 2019-05-04  7000   5500     4000       5000
# 2019-05-05  5500   4500     3000       4000

# %%
team_df['toto'].sum()
# Out:
# 22000

# %%
team_df.count()
# Out:
# toto         5
# apple        5
# gildong      5
# catanddog    5
# dtype: int64

# %%
team_df.count().index
# Out:
# Index(['toto', 'apple', 'gildong', 'catanddog'], dtype='object')

# %%
team_df[['toto','gildong']].sum()
# Out:
# toto       22000
# gildong    14500
# dtype: int64

# %%
print(team_df[['apple','catanddog']].sum() ,end='\n\n')
print(team_df[['apple','catanddog']].mean(),end='\n\n')
print(team_df[['apple','catanddog']].std(),end='\n\n')
# Out:
# apple        25000
# catanddog    24000
# dtype: int64
#
# apple        5000.0
# catanddog    4800.0
# dtype: float64
#
# apple         790.569415
# catanddog    1483.239697
# dtype: float64

# %%
team_df['row_sum'] = team_df.sum(axis=1)
team_df
# Out:
#             toto  apple  gildong  catanddog  row_sum
# 2019-05-01  1500   4000     2000       7000    14500
# 2019-05-02  3000   5000     2500       5000    15500
# 2019-05-03  5000   6000     3000       3000    17000
# 2019-05-04  7000   5500     4000       5000    21500
# 2019-05-05  5500   4500     3000       4000    17000

# %%
import seaborn as sns

t = sns.load_dataset("titanic")
t
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
# 나이 데이터만 보기
print(t['age'])
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
# 두 개의 열(나이,항구) 선택
sel = ['age','embarked']
t[sel]
# Out:
#       age embarked
# 0    22.0        S
# 1    38.0        C
# 2    26.0        S
# 3    35.0        S
# 4    35.0        S
# ..    ...      ...
# 886  27.0        S
# 887  19.0        S
# 888   NaN        S
# 889  26.0        C
# 890  32.0        Q
#
# [891 rows x 2 columns]

# %%
t
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
t.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
t.shape
# Out:
# (891, 15)

# %%
team_df
# Out:
#             toto  apple  gildong  catanddog  row_sum
# 2019-05-01  1500   4000     2000       7000    14500
# 2019-05-02  3000   5000     2500       5000    15500
# 2019-05-03  5000   6000     3000       3000    17000
# 2019-05-04  7000   5500     4000       5000    21500
# 2019-05-05  5500   4500     3000       4000    17000

# %%
team_df['row_sum'].sort_values(ascending=False)
# Out:
# 2019-05-04    21500
# 2019-05-03    17000
# 2019-05-05    17000
# 2019-05-02    15500
# 2019-05-01    14500
# Name: row_sum, dtype: int64

# %%
team_df
# Out:
#             toto  apple  gildong  catanddog  row_sum
# 2019-05-01  1500   4000     2000       7000    14500
# 2019-05-02  3000   5000     2500       5000    15500
# 2019-05-03  5000   6000     3000       3000    17000
# 2019-05-04  7000   5500     4000       5000    21500
# 2019-05-05  5500   4500     3000       4000    17000

# %%
team_df.iloc[:,0:4].mean(axis=1).sort_values(ascending=False)
# Out:
# 2019-05-04    5375.0
# 2019-05-03    4250.0
# 2019-05-05    4250.0
# 2019-05-02    3875.0
# 2019-05-01    3625.0
# dtype: float64

# %%
team_df
# Out:
#             toto  apple  gildong  catanddog  row_sum
# 2019-05-01  1500   4000     2000       7000    14500
# 2019-05-02  3000   5000     2500       5000    15500
# 2019-05-03  5000   6000     3000       3000    17000
# 2019-05-04  7000   5500     4000       5000    21500
# 2019-05-05  5500   4500     3000       4000    17000

# %%
team_df.iloc[:,0:4].median(axis=1).sort_values(ascending=False)
# Out:
# 2019-05-04    5250.0
# 2019-05-05    4250.0
# 2019-05-02    4000.0
# 2019-05-03    4000.0
# 2019-05-01    3000.0
# dtype: float64

# %%
row_sum = team_df.sum(axis=1)

# %%
row_mean = team_df.mean(axis=1)

# %%
t['row_mean'] = team_df.mean(axis=1)

# %%
##행의 합이 15000 이상인 값을 뽑는다.
team_df.loc[ team_df.row_sum >= 15000 , :]
# Out:
#             toto  apple  gildong  catanddog  row_sum
# 2019-05-02  3000   5000     2500       5000    15500
# 2019-05-03  5000   6000     3000       3000    17000
# 2019-05-04  7000   5500     4000       5000    21500
# 2019-05-05  5500   4500     3000       4000    17000

# %%
team_df.loc[ (team_df.row_sum >= 15000) & (team_df.toto>= 4000) , :]
# Out:
#             toto  apple  gildong  catanddog  row_sum
# 2019-05-03  5000   6000     3000       3000    17000
# 2019-05-04  7000   5500     4000       5000    21500
# 2019-05-05  5500   4500     3000       4000    17000

# %%
data = sns.load_dataset("titanic")
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
sns.histplot(data.fare)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %%
sns.boxplot(data.fare)
# Out:
# C:\Users\hingu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='fare'>

# %%
data.fare.describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: fare, dtype: float64

# %%
## 0 ~ 7.9104 -> 1번 그룹
## 7.9104 ~ 14.4542 -> 2번 그룹
## 14.4542 ~ 31.00 -> 3번 그룹
## 31.00 ~ 512 -> 4번 그룹

# %%
data_fare01 = data.loc[(data.fare >= 0) & (data.fare <= 7.9104), :]

# %%
print(data_fare01.shape)
# Out:
# (223, 15)

# %%
data_fare01 = data.loc[(data.fare >= 0) & (data.fare <= 7.9104), :]
data_fare02 = data.loc[(data.fare > 7.9104) & (data.fare <= 14.4542), :]
data_fare03 = data.loc[(data.fare > 14.4542) & (data.fare <= 31), :]
data_fare04 = data.loc[(data.fare > 31) & (data.fare <= 512), :]

# %%
print(data_fare01.shape)
print(data_fare02.shape)
print(data_fare03.shape)
print(data_fare04.shape)
# Out:
# (223, 15)
# (224, 15)
# (222, 15)
# (219, 15)

# %%
data_fare01.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch    fare embarked  class  \
# 0          0       3    male  22.0      1      0  7.2500        S  Third
# 14         0       3  female  14.0      0      0  7.8542        S  Third
# 19         1       3  female   NaN      0      0  7.2250        C  Third
# 26         0       3    male   NaN      0      0  7.2250        C  Third
# 28         1       3  female   NaN      0      0  7.8792        Q  Third
#
#       who  adult_male deck  embark_town alive  alone
# 0     man        True  NaN  Southampton    no  False
# 14  child       False  NaN  Southampton    no   True
# 19  woman       False  NaN    Cherbourg   yes   True
# 26    man        True  NaN    Cherbourg    no   True
# 28  woman       False  NaN   Queenstown   yes   True

# %%
sns.histplot(data_fare01['fare'])
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %%
data_fare02.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 2          1       3  female  26.0      0      0   7.9250        S  Third
# 4          0       3    male  35.0      0      0   8.0500        S  Third
# 5          0       3    male   NaN      0      0   8.4583        Q  Third
# 8          1       3  female  27.0      0      2  11.1333        S  Third
# 12         0       3    male  20.0      0      0   8.0500        S  Third
#
#       who  adult_male deck  embark_town alive  alone
# 2   woman       False  NaN  Southampton   yes   True
# 4     man        True  NaN  Southampton    no   True
# 5     man        True  NaN   Queenstown    no   True
# 8   woman       False  NaN  Southampton   yes  False
# 12    man        True  NaN  Southampton    no   True

# %%
sns.histplot(data_fare02['fare'])
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %%
data_fare03.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 11         1       1  female  58.0      0      0  26.5500        S   First
# 15         1       2  female  55.0      0      0  16.0000        S  Second
#
#       who  adult_male deck  embark_town alive  alone
# 7   child       False  NaN  Southampton    no  False
# 9   child       False  NaN    Cherbourg   yes  False
# 10  child       False    G  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True
# 15  woman       False  NaN  Southampton   yes   True

# %%
sns.histplot(data_fare03['fare'])
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %%
data_fare04.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 3          1       1  female  35.0      1      0  53.1000        S  First
# 6          0       1    male  54.0      0      0  51.8625        S  First
# 13         0       3    male  39.0      1      5  31.2750        S  Third
# 23         1       1    male  28.0      0      0  35.5000        S  First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 3   woman       False    C  Southampton   yes  False
# 6     man        True    E  Southampton    no   True
# 13    man        True  NaN  Southampton    no  False
# 23    man        True    A  Southampton   yes   True

# %%
sns.histplot(data_fare04['fare'])
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %%
data.loc[(data.fare >= 0) & (data.fare <= 7.9104), "group_fare"] = 1
data.loc[(data.fare > 7.9104) & (data.fare <= 14.4542), "group_fare"] = 2
data.loc[(data.fare > 14.4542) & (data.fare <= 31), "group_fare"] = 3
data.loc[(data.fare > 31) & (data.fare <= 512), "group_fare"] = 4

data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  group_fare
# 0      man        True  NaN  Southampton    no  False         1.0
# 1    woman       False    C    Cherbourg   yes  False         4.0
# 2    woman       False  NaN  Southampton   yes   True         2.0
# 3    woman       False    C  Southampton   yes  False         4.0
# 4      man        True  NaN  Southampton    no   True         2.0
# ..     ...         ...  ...          ...   ...    ...         ...
# 886    man        True  NaN  Southampton    no   True         2.0
# 887  woman       False    B  Southampton   yes   True         3.0
# 888  woman       False  NaN  Southampton    no  False         3.0
# 889    man        True    C    Cherbourg   yes   True         3.0
# 890    man        True  NaN   Queenstown    no   True         1.0
#
# [891 rows x 16 columns]

# %%
sns.histplot(data.age)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
data.age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: age, dtype: float64

# %%
# 1 : 0~20 // 2: 20~28 // 3: 28~38 // 4 : 38~80

data_age01 = data.loc[(data.age >= 0) & (data.age <= 20.125), :]
data_age02 = data.loc[(data.age > 20.125) & (data.age <= 28),:]
data_age03 = data.loc[(data.age > 28) & (data.age <= 38), :]
data_age04 = data.loc[(data.age > 38) & (data.age <= 80), :]

# %%
data.loc[(data.age >= 0) & (data.age <= 20.125), "group_age"] =1
data.loc[(data.age > 20.125) & (data.age  <= 28),  "group_age"] = 2
data.loc[(data.age  > 28) & (data.age  <= 38),  "group_age"] = 3
data.loc[(data.age  > 38) & (data.age  <= 80),  "group_age"] = 4

# %%
data_age01.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 12         0       3    male  20.0      0      0   8.0500        S   Third
# 14         0       3  female  14.0      0      0   7.8542        S   Third
#
#       who  adult_male deck  embark_town alive  alone  group_fare  group_age
# 7   child       False  NaN  Southampton    no  False         3.0        2.0
# 9   child       False  NaN    Cherbourg   yes  False         3.0        3.0
# 10  child       False    G  Southampton   yes  False         3.0        1.0
# 12    man        True  NaN  Southampton    no   True         2.0        1.0
# 14  child       False  NaN  Southampton    no   True         1.0        1.0

# %%
sns.histplot(data_age01['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
data_age02.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0          0       3    male  22.0      1      0   7.2500        S  Third
# 2          1       3  female  26.0      0      0   7.9250        S  Third
# 8          1       3  female  27.0      0      2  11.1333        S  Third
# 23         1       1    male  28.0      0      0  35.5000        S  First
# 34         0       1    male  28.0      1      0  82.1708        C  First
#
#       who  adult_male deck  embark_town alive  alone  group_fare  group_age
# 0     man        True  NaN  Southampton    no  False         1.0        NaN
# 2   woman       False  NaN  Southampton   yes   True         2.0        NaN
# 8   woman       False  NaN  Southampton   yes  False         2.0        NaN
# 23    man        True    A  Southampton   yes   True         4.0        3.0
# 34    man        True  NaN    Cherbourg    no  False         4.0        NaN

# %%
sns.histplot(data_age02['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
data_age03.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 18         0       3  female  31.0      1      0  18.0000        S   Third
# 20         0       2    male  35.0      0      0  26.0000        S  Second
#
#       who  adult_male deck  embark_town alive  alone  group_fare  group_age
# 1   woman       False    C    Cherbourg   yes  False         4.0        4.0
# 3   woman       False    C  Southampton   yes  False         4.0        4.0
# 4     man        True  NaN  Southampton    no   True         2.0        NaN
# 18  woman       False  NaN  Southampton    no  False         3.0        NaN
# 20    man        True  NaN  Southampton    no   True         3.0        2.0

# %%
sns.histplot(data_age03['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
data_age04.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 11         1       1  female  58.0      0      0  26.5500        S   First
# 13         0       3    male  39.0      1      5  31.2750        S   Third
# 15         1       2  female  55.0      0      0  16.0000        S  Second
# 30         0       1    male  40.0      0      0  27.7208        C   First
#
#       who  adult_male deck  embark_town alive  alone  group_fare  group_age
# 6     man        True    E  Southampton    no   True         4.0        4.0
# 11  woman       False    C  Southampton   yes   True         3.0        2.0
# 13    man        True  NaN  Southampton    no  False         4.0        3.0
# 15  woman       False  NaN  Southampton   yes   True         3.0        NaN
# 30    man        True  NaN    Cherbourg    no   True         3.0        2.0

# %%
sns.histplot(data_age04['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
data.loc[(data.age >= 0) & (data.age <= 20.125), "group_age"] =1
data.loc[(data.age > 20.125) & (data.age <= 28),"group_age"] = 2
data.loc[(data.age > 28) & (data.age <= 38),  "group_age"] = 3
data.loc[(data.age > 38) ,  "group_age"] = 4

grp_age_01 = data[data['group_age']==1]
grp_age_02 = data[data['group_age']==2]
grp_age_03 = data[data['group_age']==3]
grp_age_04 = data[data['group_age']==4]

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  group_fare  group_age
# 0      man        True  NaN  Southampton    no  False         1.0        2.0
# 1    woman       False    C    Cherbourg   yes  False         4.0        3.0
# 2    woman       False  NaN  Southampton   yes   True         2.0        2.0
# 3    woman       False    C  Southampton   yes  False         4.0        3.0
# 4      man        True  NaN  Southampton    no   True         2.0        3.0
# ..     ...         ...  ...          ...   ...    ...         ...        ...
# 886    man        True  NaN  Southampton    no   True         2.0        2.0
# 887  woman       False    B  Southampton   yes   True         3.0        1.0
# 888  woman       False  NaN  Southampton    no  False         3.0        2.0
# 889    man        True    C    Cherbourg   yes   True         3.0        2.0
# 890    man        True  NaN   Queenstown    no   True         1.0        3.0
#
# [891 rows x 17 columns]

# %%
data.groupby(['group_fare']).mean()
# Out:
#             survived    pclass        age     sibsp     parch       fare  \
# group_fare
# 1.0         0.197309  2.919283  28.328671  0.053812  0.022422   7.034172
# 2.0         0.303571  2.616071  28.989600  0.147321  0.098214  10.386050
# 3.0         0.454955  2.225225  29.086610  0.752252  0.612613  23.028677
# 4.0         0.575342  1.474886  31.947225  1.159817  0.803653  82.874429
#
#             adult_male     alone  group_age
# group_fare
# 1.0           0.802691  0.941704   2.307692
# 2.0           0.683036  0.834821   2.405000
# 3.0           0.500000  0.342342   2.500000
# 4.0           0.420091  0.283105   2.778302

# %%
data.groupby(['group_fare']).sum()
# Out:
#             survived  pclass      age  sibsp  parch        fare  adult_male  \
# group_fare
# 1.0               44     651  4051.00     12      5   1568.6203         179
# 2.0               68     586  5797.92     33     22   2326.4752         153
# 3.0              101     494  5148.33    167    136   5112.3662         111
# 4.0              126     323  6101.92    254    176  18149.5000          92
#
#             alone  group_age
# group_fare
# 1.0           210      330.0
# 2.0           187      481.0
# 3.0            76      505.0
# 4.0            62      589.0

# %%
data.groupby(['group_fare']).median()
# Out:
#             survived  pclass   age  sibsp  parch      fare  adult_male  alone  \
# group_fare
# 1.0                0       3  25.0      0      0   7.75000         1.0    1.0
# 2.0                0       3  28.0      0      0   9.84375         1.0    1.0
# 3.0                0       2  30.0      1      0  25.46670         0.5    0.0
# 4.0                1       1  31.0      1      0  69.30000         0.0    0.0
#
#             group_age
# group_fare
# 1.0               2.0
# 2.0               2.0
# 3.0               3.0
# 4.0               3.0

# %%
data.groupby(['group_fare']).count()
# Out:
#             survived  pclass  sex  age  sibsp  parch  fare  embarked  class  \
# group_fare
# 1.0              223     223  223  143    223    223   223       223    223
# 2.0              224     224  224  200    224    224   224       224    224
# 3.0              222     222  222  177    222    222   222       222    222
# 4.0              219     219  219  191    219    219   219       217    219
#
#             who  adult_male  deck  embark_town  alive  alone  group_age
# group_fare
# 1.0         223         223     8          223    223    223        143
# 2.0         224         224    16          224    224    224        200
# 3.0         222         222    41          222    222    222        202
# 4.0         219         219   136          217    219    219        212

# %%
sel = ['pclass', 'sex', 'age', 'fare', 'group_fare']
data[sel].groupby(['group_fare']).count()
# Out:
#             pclass  sex  age  fare
# group_fare
# 1.0            223  223  143   223
# 2.0            224  224  200   224
# 3.0            222  222  177   222
# 4.0            219  219  191   219

# %%
data.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone', 'group_fare', 'group_age'],
#       dtype='object')

# %%
sel = ['pclass','sex','age','fare','survived','group_fare']
data[sel].groupby(['group_fare']).mean()
# Out:
#               pclass        age       fare  survived
# group_fare
# 1.0         2.919283  28.328671   7.034172  0.197309
# 2.0         2.616071  28.989600  10.386050  0.303571
# 3.0         2.225225  29.086610  23.028677  0.454955
# 4.0         1.474886  31.947225  82.874429  0.575342

# %%
data.groupby(['group_age']).mean()
# Out:
#            survived    pclass        age     sibsp     parch       fare  \
# group_age
# 1.0        0.458101  2.569832  12.651788  1.039106  0.759777  29.853074
# 2.0        0.354680  2.403941  24.374317  0.413793  0.285714  28.578508
# 3.0        0.442623  2.114754  32.880000  0.327869  0.240437  38.526137
# 4.0        0.369231  1.830769  49.299435  0.600000  0.492308  43.101731
#
#            adult_male     alone  group_fare
# group_age
# 1.0          0.346369  0.368715    2.631285
# 2.0          0.650246  0.640394    2.334975
# 3.0          0.661202  0.650273    2.577778
# 4.0          0.656410  0.574359    3.015385

# %%
data.groupby(['sex','pclass','embarked','group_age']).count()
# Out:
#                                   survived  age  sibsp  parch  fare  class  \
# sex    pclass embarked group_age
# female 1      C        1.0               5    5      5      5     5      5
#                        2.0               7    7      7      7     7      7
#                        3.0               9    9      9      9     9      9
#                        4.0              18   17     18     18    18     18
#               Q        3.0               1    1      1      1     1      1
#               S        1.0               9    9      9      9     9      9
#                        2.0               8    8      8      8     8      8
#                        3.0              13   13     13     13    13     13
#                        4.0              17   14     17     17    17     17
#        2      C        1.0               3    3      3      3     3      3
#                        2.0               4    4      4      4     4      4
#               Q        3.0               1    1      1      1     1      1
#               S        1.0              13   13     13     13    13     13
#                        2.0              18   18     18     18    18     18
#                        3.0              20   19     20     20    20     20
#                        4.0              16   16     16     16    16     16
#        3      C        1.0              13   13     13     13    13     13
#                        2.0               3    1      3      3     3      3
#                        3.0               1    1      1      1     1      1
#                        4.0               1    1      1      1     1      1
#               Q        1.0               5    5      5      5     5      5
#                        2.0               4    2      4      4     4      4
#                        3.0               2    2      2      2     2      2
#                        4.0               1    1      1      1     1      1
#               S        1.0              29   29     29     29    29     29
#                        2.0              27   23     27     27    27     27
#                        3.0              14   14     14     14    14     14
#                        4.0              13   10     13     13    13     13
# male   1      C        1.0               2    2      2      2     2      2
#                        2.0              12   10     12     12    12     12
#                        3.0               9    7      9      9     9      9
#                        4.0              18   17     18     18    18     18
#               Q        4.0               1    1      1      1     1      1
#               S        1.0               5    5      5      5     5      5
#                        2.0              10    6     10     10    10     10
#                        3.0              22   17     22     22    22     22
#                        4.0              39   36     39     39    39     39
#        2      C        1.0               1    1      1      1     1      1
#                        2.0               2    2      2      2     2      2
#                        3.0               5    5      5      5     5      5
#               Q        4.0               1    1      1      1     1      1
#               S        1.0              18   18     18     18    18     18
#                        2.0              23   23     23     23    23     23
#                        3.0              26   26     26     26    26     26
#                        4.0              23   23     23     23    23     23
#        3      C        1.0               8    8      8      8     8      8
#                        2.0               8    7      8      8     8      8
#                        3.0               8    8      8      8     8      8
#                        4.0               2    2      2      2     2      2
#               Q        1.0               5    5      5      5     5      5
#                        2.0               5    2      5      5     5      5
#                        3.0               3    3      3      3     3      3
#                        4.0               4    4      4      4     4      4
#               S        1.0              63   63     63     63    63     63
#                        2.0              72   70     72     72    72     72
#                        3.0              48   48     48     48    48     48
#                        4.0              40   33     40     40    40     40
#
#                                   who  adult_male  deck  embark_town  alive  \
# sex    pclass embarked group_age
# female 1      C        1.0          5           5     5            5      5
#                        2.0          7           7     7            7      7
#                        3.0          9           9     6            9      9
#                        4.0         18          18    15           18     18
#               Q        3.0          1           1     1            1      1
#               S        1.0          9           9     9            9      9
#                        2.0          8           8     6            8      8
#                        3.0         13          13    12           13     13
#                        4.0         17          17    16           17     17
#        2      C        1.0          3           3     0            3      3
#                        2.0          4           4     1            4      4
#               Q        3.0          1           1     0            1      1
#               S        1.0         13          13     1           13     13
#                        2.0         18          18     2           18     18
#                        3.0         20          20     4           20     20
#                        4.0         16          16     1           16     16
#        3      C        1.0         13          13     0           13     13
#                        2.0          3           3     1            3      3
#                        3.0          1           1     0            1      1
#                        4.0          1           1     0            1      1
#               Q        1.0          5           5     0            5      5
#                        2.0          4           4     0            4      4
#                        3.0          2           2     0            2      2
#                        4.0          1           1     0            1      1
#               S        1.0         29          29     2           29     29
#                        2.0         27          27     2           27     27
#                        3.0         14          14     1           14     14
#                        4.0         13          13     0           13     13
# male   1      C        1.0          2           2     2            2      2
#                        2.0         12          12     8           12     12
#                        3.0          9           9     7            9      9
#                        4.0         18          18    14           18     18
#               Q        4.0          1           1     1            1      1
#               S        1.0          5           5     5            5      5
#                        2.0         10          10     6           10     10
#                        3.0         22          22    19           22     22
#                        4.0         39          39    30           39     39
#        2      C        1.0          1           1     0            1      1
#                        2.0          2           2     0            2      2
#                        3.0          5           5     1            5      5
#               Q        4.0          1           1     0            1      1
#               S        1.0         18          18     3           18     18
#                        2.0         23          23     0           23     23
#                        3.0         26          26     2           26     26
#                        4.0         23          23     0           23     23
#        3      C        1.0          8           8     0            8      8
#                        2.0          8           8     0            8      8
#                        3.0          8           8     0            8      8
#                        4.0          2           2     0            2      2
#               Q        1.0          5           5     0            5      5
#                        2.0          5           5     0            5      5
#                        3.0          3           3     0            3      3
#                        4.0          4           4     0            4      4
#               S        1.0         63          63     2           63     63
#                        2.0         72          72     1           72     72
#                        3.0         48          48     1           48     48
#                        4.0         40          40     1           40     40
#
#                                   alone  group_fare
# sex    pclass embarked group_age
# female 1      C        1.0            5           5
#                        2.0            7           7
#                        3.0            9           8
#                        4.0           18          18
#               Q        3.0            1           1
#               S        1.0            9           9
#                        2.0            8           8
#                        3.0           13          13
#                        4.0           17          17
#        2      C        1.0            3           3
#                        2.0            4           4
#               Q        3.0            1           1
#               S        1.0           13          13
#                        2.0           18          18
#                        3.0           20          20
#                        4.0           16          16
#        3      C        1.0           13          13
#                        2.0            3           3
#                        3.0            1           1
#                        4.0            1           1
#               Q        1.0            5           5
#                        2.0            4           4
#                        3.0            2           2
#                        4.0            1           1
#               S        1.0           29          29
#                        2.0           27          27
#                        3.0           14          14
#                        4.0           13          13
# male   1      C        1.0            2           2
#                        2.0           12          12
#                        3.0            9           7
#                        4.0           18          18
#               Q        4.0            1           1
#               S        1.0            5           5
#                        2.0           10          10
#                        3.0           22          22
#                        4.0           39          39
#        2      C        1.0            1           1
#                        2.0            2           2
#                        3.0            5           5
#               Q        4.0            1           1
#               S        1.0           18          18
#                        2.0           23          23
#                        3.0           26          26
#                        4.0           23          23
#        3      C        1.0            8           8
#                        2.0            8           8
#                        3.0            8           8
#                        4.0            2           2
#               Q        1.0            5           5
#                        2.0            5           5
#                        3.0            3           3
#                        4.0            4           4
#               S        1.0           63          63
#                        2.0           72          72
#                        3.0           48          48
#                        4.0           40          40
