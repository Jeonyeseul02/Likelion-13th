# %%
### 나눔 고딕 설치
# !apt-get update -qq   # 설치를 업데이트 
# !apt-get install fonts-nanum* -qq  # 설치한다. fonts-nanum*
# Out:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 155047 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Selecting previously unselected package fonts-nanum-eco.
# Preparing to unpack .../fonts-nanum-eco_1.000-6_all.deb ...
# Unpacking fonts-nanum-eco (1.000-6) ...
# Selecting previously unselected package fonts-nanum-extra.
# Preparing to unpack .../fonts-nanum-extra_20170925-1_all.deb ...
# Unpacking fonts-nanum-extra (20170925-1) ...
# Selecting previously unselected package fonts-nanum-coding.
# Preparing to unpack .../fonts-nanum-coding_2.5-1_all.deb ...
# Unpacking fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-extra (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Setting up fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-eco (1.000-6) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...

# %%
import matplotlib.font_manager as fm # 폰트 관련 용도
import matplotlib.pyplot as plt      # 그래프 그리는 용도

path = '/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf' # 설치된 나눔 글꼴중 원하는 녀석의 전체
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

# 우선 fm._rebuild() 를 해주고 # 폰트 매니저 재빌드가 필요하다.
fm._rebuild()
# Out:
# NanumGothic Eco

# %%
# %matplotlib inline
import matplotlib as mpl # 기본 설정 만지는 용도
import matplotlib.pyplot as plt # 그래프 그리는 용도
import matplotlib.font_manager as fm # 폰트 관련 용도
import numpy as np

path = '/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf' # 설치된 나눔글꼴중 원하는 녀석의 전체
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

## 음수 표시되도록 설정
mpl.rcParams['axes.unicode_minus'] = False
# Out:
# NanumGothic Eco

# %%
pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.5.2-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 7.3 MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 56.4 MB/s
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Collecting beautifulsoup4==4.6.0
#   Downloading beautifulsoup4-4.6.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 6.7 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Installing collected packages: JPype1, colorama, beautifulsoup4, konlpy
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-1.3.0 beautifulsoup4-4.6.0 colorama-0.4.4 konlpy-0.5.2

# %%
import nltk
from konlpy.tag import Kkma
from konlpy.tag import Hannanum

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image

# %%
text = open("해외_코로나_현황_뉴스_1000.csv").read()
text
# Out:
# '언론사\n"장하성 ""코로나 아니면 시진핑 왔을 것""…""왕이는 어떻게 왔나"""\n"與 ""이달 말 \'위드 코로나\' 가야…경구 치료제 무료제공도 검토"""\n"[코로나19 발생현황] 10월 6일 0시 기준, 신규 확진자 2,028명"\n"러시아 반도체 부품, LED시장 현황"\n[그래픽] 코로나19 확진자 지역별 현황(6일)\n코로나 글로벌 백신 전쟁 속 \'한국 자급률 27%\' 불과\n[상보][코로나19] 신규 확진자 2028명…사흘만에 다시 2000명대\n경남에서 코로나19 확진자 60명 추가…도내 하루 97명 감염\n코로나19 확진 1575명·연이틀 1천명대…91일째 네 자릿수(종합)\n[코로나 현황] 신규 확진자 2028명…사흘만에 다시 2000명대\n부산 초등학교·어린이집 코로나19 집단감염 발생\n"[코로나19 발생현황] 10월 6일 0시 기준, 신규 확진자 2,028명"\n"[속보]전남 코로나 확진자 13명 추가, 목포·여수·순청·광양 등"\n"김용판 의원, 코로나 상황에도 “해외 도피범죄자 매년 늘어”"\n[그래픽] 코로나19 확진자 지역별 현황(5일)\n"[코로나19 발생현황] 신규 확진자 2028명, 사흘만에 다시 2000명대... 치명률..."\n"10월 5일, 서울시 코로나19 발생 현황"\n코로나19 2028명 확진…\'연휴 효과\' 사라져 사흘 만에 다시 2천 명대(종합)\n[속보] 오늘 코로나19 실시간 확진자수 \'2천명\' 또 넘겨\n"해외서 더 잘 팔린 신라면… 농심, \'글로벌 시장 공략\' 박차"\n코로나19 회복세? 올들어 불법 외환거래 증가\n"[상보][코로나19] 신규 확진자 1575명, 이틀 연속 1000명대…확산세 여전"\n"정부, 국산 코로나19 백신·치료제 지원에 내년 5265억원 투입"\n[전문] 대구 `코로나19` 신규 확진자 50명 발생\n"[코로나19 발생현황] 10월 5일 0시 기준, 신규 확진자 1,575명"\n\'위드코로나\' 시대의 불평등 해소와 시민권 보장 방안은\n"“이노비즈기업, 코로나19 위기에도 고성장”"\n코로나19 1673명 확진…11일 만에 2천 명 밑돌아·90일째 네 자릿수(종합)\n"10월 4일, 서울시 코로나19 발생 현황"\n[그래픽] 코로나19 확진자 지역별 현황(4일)\n"[코로나19 발생현황] 신규 확진자 1575명, 연휴영향에 이틀째 1000명대... 치..."\n"코로나 19 신규 확진 2,427명 국내확진 2,400명, 해외유입 27명"\n[속보] 오늘 코로나19 실시간 확진자수 \'1천9백명\' 육박\n"[속보]경북 코로나 확진자 55명 추가 발생, 경산·구미·영천·칠곡 등"\n"라면업계, 해외 매출이 국내 넘어서자 수출 경쟁 활발"\n’위드 코로나’ 도입 전망… ‘백신 접종 인증 앱’ 이용 현황 분석\n대구 코로나19 신규 확진자 64명 총 1만5904명…사망 늘어\n코로나19 2486명 확진·8일째 \'요일 최다\'…거리두기 2주 재연장(종합)\n"[코로나19 발생현황] 10월 4일 0시 기준, 신규 확진자 1,673명"\n"미접종자 예약률 6.1%…질병청 ""백신패스, 위드코로나 안전장치""(종합)"\n"[코로나19 발생현황] 신규확진 1673명, 연휴 영향에 11일만에 2천명 아래로"\n코로나19 신규 확진 1673명… 11일 만에 2000명대 아래\n[코로나 현황] 신규 확진 1673명…11일만에 2000명대 아래로\n내년도 코로나19 치료제·백신개발에 5265억 지원\n해외예방접종완료자도 쿠브 통해 접종이력 확인 가능\n[그래픽] 코로나19 확진자 지역별 현황(2일)\n"국내 주요 시도별 코로나19 발생 현황은?…10월 6일 신규 확진자 2,028명, 총..."\n[그래픽] 코로나19 확진자 지역별 현황(3일)\n"국내 코로나19 하루 확진 다시 2천 명대로, 수도권이 74.7% 차지"\n[그래픽] 코로나19 확진자 지역별 현황(1일)\n10월 5일 0시 기준 국내 주요 지역 권역별 코로나19 집단감염 발생현황은?\n"국내 코로나19 하루 확진 1575명으로 줄어, 이틀째 1천 명대로 불안"\n코로나19 신규 확진자 2248명…88일째 네 자릿수\n"경북도, 코로나19 60명 확진…13곳서 발생"\n[전문] 대구 `코로나19` 신규 확진자 68명 발생\n[속보]코로나19 실시간 확진자수 \'또 2천명\' 육박\n[그래픽] 코로나19 확진자 지역별 현황(28일)\n"[코로나19 발생현황] 10월 2일 0시 기준, 신규 확진자 2,248명"\n코로나19 신규 확진 2486명… 수도권 76.7%\n[그래픽] 코로나19 확진자 지역별 현황(30일)\n코로나19 신규확진 2885명·역대 2번째…엿새째 요일 \'최다 경신\'(종합)\n[코로나 그래픽] 신규 확진 이틀째 2천명대로 증가\n내년 코로나19 치료제·백신 개발 5265억 투입\n"국내 코로나19 하루 확진 2086명으로 확산세, 수도권 73.9% 차지"\n"코로나19 신규 확진자 2,885명…접종 완료율 48%"\n추석에도 방심 못할 코로나19…월요일 최다 1729명 확진(종합)\n필리핀 경제 현황 및 전망\n"[코로나19 발생현황] 신규 확진자 2086명, 주말 두번째 규모…치명률 0.79%"\n"10월 5일 주요 시도별 코로나19 발생 현황은?…국내 신규 확진자 1,575명, 총..."\n"[국내 코로나19 현황] 21시기준 23명 늘어나 다시 2천명대, 2101명 발생"\n[그래픽] 코로나19 확진자 지역별 현황(29일)\n코로나19 신규확진 2289명…월요일 집계기준 \'역대 최다\' 경신(종합)\n"[코로나19 발생현황] 10월 3일 0시 기준, 신규 확진자 2,086명"\n"공정위, 아시아 소비자 정책포럼…해외직구 소비자 보호 논의"\n"김용판 의원, 국민들은 잘 못가는 해외, 범죄자는 잘 간다. 작년 한 해만 범죄..."\n"""건강 안전 최우선"" 방탄소년단, 코로나 뚫고 11월 LA스타디움 대면 콘서트 개..."\n[속보]코로나19 실시간 확진자수 \'1천5백여명\' 주춤\n"국민연금, 7월 말 수익률 8.55%…해외주식 21.06%"\n"[코로나19 발생현황] 10월 1일 0시 기준, 신규 확진자 2,486명"\n코로나 확진자 2564명 \'일주일 연속 요일 최다\'… 거리두기 연장되나\n코로나19 신규확진 2564명… 86일째 네자릿수 기록\n"[코로나19 발생현황] 9월 30일 0시 기준, 신규 확진자 2,564명"\n10월 4일 0시 기준 국내 주요 지역 권역별 코로나19 집단감염 발생현황은?\n[코로나 현황] 신규 확진자 2885명…역대 두 번째 최다 기록\n[코로나 그래픽] 신규 확진 이틀째 1천명대\n"9월 30일, 서울시 코로나19 발생 현황"\n"[코로나19 발생현황] 신규 확진자 2486명, 유행 이후 5번째 규모... 치명률 0..."\n"코로나 검사만 5번…""그래도 사이판 바다는 좋았어요"""\n"코로나19 안전신고 개통 후 신고된 내용 중 과태료 부과 362건, 고발 193건"\n[전문] 대구 `코로나19` 확진자 85명...외국인 집단감염만 44명\n[전문] 대구 `코로나19` 확진자 58명 확진\n[그래픽] 코로나19 확진자 지역별 현황(27일)\n코로나19 신규 확진자 2771명...치명률은 0.81%\n베트남 외국인직접투자 현황과 반등을 위한 방역정책 방향\n"[코로나19 발생현황] 신규 확진자 2885명, 두번째 큰 규모... 치명률 0.80%"\n코로나19 신규확진 2564명·1주째 \'요일 최다\'…거리두기 재연장 가닥(종합)\n[종합] 코로나 확진자 2000명대 6일째 지속…꺾이지 않는 수도권 확산세\n코로나19 신규확진 2434명·역대 최다치…\'추석 후폭풍\' 현실화(종합)\n"9월 29일, 서울시 코로나19 발생 현황"\n"[코로나19 발생현황] 신규 확진자 2564명, 1주일 연속 \'요일 최다\'… 치명률 ..."\n"[코로나19 발생현황] 신규 확진자 2086명, 주말 두번째 규모…치명률 0.79%"\n토종 코로나백신ㆍ치료제 개발에 5265억원 쏜다\n"10월 5일 주요 시도별 코로나19 발생 현황은?…국내 신규 확진자 1,575명, 총..."\n"[국내 코로나19 현황] 21시기준 23명 늘 ...

# %%
print(STOPWORDS)
# Out:
# {'few', 'hers', 'it', 'then', "wasn't", 'during', 'am', 'you', 'any', 'of', 'above', 'cannot', "you'll", "doesn't", 'from', 'does', 'was', 'i', "isn't", 'just', 'like', 'not', 'can', "here's", 'shall', "hasn't", 'before', 'each', 'about', 'she', 'should', "weren't", 'me', 'who', 'myself', 'my', 'up', 'for', 'www', 'there', 'get', 'ought', "when's", 'what', 'r', 'through', 'how', 'his', 'if', 'some', "you'd", "i'll", 'in', 'to', 'that', "why's", 'or', "mustn't", "he's", 'when', "shan't", 'be', 'this', 'herself', 'only', 'being', 'by', 'itself', 'ever', 'into', 'doing', 'where', 'been', "didn't", "he'd", 'which', 'once', 'because', "let's", 'were', "wouldn't", "we've", 'yourselves', "they'll", 'its', 'and', 'until', 'an', 'all', 'yourself', "i'd", 'http', "can't", 'between', 'these', "we'll", 'with', 'so', 'such', 'down', 'off', 'other', "couldn't", 'both', 'as', 'could', "they've", "don't", 'under', 'a', "shouldn't", "that's", "who's", 'ours', 'same', 'we', 'while', 'them', 'would', 'here', 'are', 'did', "she'd", 'ourselves', 'out', 'why', 'below', 'their', 'your', 'on', 'otherwise', "she's", 'the', 'very', "you're", "they'd", 'else', 'nor', "i've", 'at', 'however', "she'll", 'has', 'having', 'theirs', "they're", "what's", 'no', "i'm", 'against', "won't", 'him', "where's", 'again', 'further', "how's", 'do', 'he', 'than', 'whom', "aren't", 'most', 'since', "there's", 'own', "hadn't", 'but', 'had', 'also', 'have', 'those', "he'll", "it's", 'too', 'k', 'is', 'yours', 'they', 'more', 'our', 'over', 'her', 'com', "we'd", 'himself', "you've", "we're", "haven't", 'themselves', 'after'}

# %%
from konlpy.tag import Okt   ### Okt
t = Okt()

#from konlpy.tag import Kkma  ### Okt
#t = Kkma()
doc_nouns = t.nouns(text)
print( len( doc_nouns ) )
doc_nouns
# Out:
# 9146
# ['언론사',
#  '장하',
#  '코로나',
#  '시진핑',
#  '것',
#  '왕',
#  '달',
#  '말',
#  '위드',
#  '코로나',
#  '가야',
#  '경구',
#  '치료',
#  '제',
#  '무료',
#  '제공',
#  '검토',
#  '코로나',
#  '발생',
#  '현황',
#  '기준',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '러시아',
#  '반도체',
#  '부품',
#  '시장',
#  '현황',
#  '그래픽',
#  '코로나',
#  '확',
#  '진자',
#  '지역별',
#  '현황',
#  '코로나',
#  '글로벌',
#  '백신',
#  '전쟁',
#  '속',
#  '한국',
#  '자급',
#  '률',
#  '불과',
#  '상보',
#  '코로나',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '사흘',
#  '다시',
#  '명대',
#  '경남',
#  '코로나',
#  '확',
#  '진자',
#  '명',
#  '추가',
#  '도내',
#  '하루',
#  '명',
#  '감염',
#  '코로나',
#  '확진',
#  '명',
#  '이틀',
#  '네',
#  '자릿수',
#  '종합',
#  '코로나',
#  '현황',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '사흘',
#  '다시',
#  '명대',
#  '부산',
#  '초등학교',
#  '어린이집',
#  '코로나',
#  '집단',
#  '감염',
#  '발생',
#  '코로나',
#  '발생',
#  '현황',
#  '기준',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '속보',
#  '전남',
#  '코로나',
#  '확',
#  '진자',
#  '명',
#  '추가',
#  '목포',
#  '여수',
#  '청',
#  '광양',
#  '등',
#  '김용판',
#  '의원',
#  '코로나',
#  '상황',
#  '해외',
#  '도피',
#  '범죄자',
#  '매년',
#  '그래픽',
#  '코로나',
#  '확',
#  '진자',
#  '지역별',
#  '현황',
#  '코로나',
#  '발생',
#  '현황',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '사흘',
#  '다시',
#  '명대',
#  '치명',
#  '률',
#  '서울시',
#  '코로나',
#  '발생',
#  '현황',
#  '코로나',
#  '명',
#  '확진',
#  '연휴',
#  '효과',
#  '사흘',
#  '다시',
#  '명대',
#  '종합',
#  '속보',
#  '오늘',
#  '코로나',
#  '실시간',
#  '확진',
#  '자수',
#  '또',
#  '해외',
#  '더',
#  '신라면',
#  '농심',
#  '글로벌',
#  '시장',
#  '공략',
#  '박차',
#  '코로나',
#  '회복',
#  '세',
#  '불법',
#  '외환거래',
#  '증가',
#  '상보',
#  '코로나',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '이틀',
#  '연속',
#  '명대',
#  '확산',
#  '세',
#  '여전',
#  '정부',
#  '국산',
#  '코로나',
#  '백신',
#  '치료',
#  '제',
#  '지원',
#  '내년',
#  '투입',
#  '전문',
#  '대구',
#  '코로나',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '발생',
#  '코로나',
#  '발생',
#  '현황',
#  '기준',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '위드',
#  '코로나',
#  '시대',
#  '불평등',
#  '해소',
#  '시민권',
#  '보장',
#  '방안',
#  '노비',
#  '기업',
#  '코로나',
#  '위기',
#  '성장',
#  '코로나',
#  '명',
#  '확진',
#  '명',
#  '밑',
#  '네',
#  '자릿수',
#  '종합',
#  '서울시',
#  '코로나',
#  '발생',
#  '현황',
#  '그래픽',
#  '코로나',
#  '확',
#  '진자',
#  '지역별',
#  '현황',
#  '코로나',
#  '발생',
#  '현황',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '연휴',
#  '영향',
#  '이틀',
#  '명대',
#  '치',
#  '코로나',
#  '신규',
#  '확진',
#  '명',
#  '국내',
#  '확진',
#  '명',
#  '해외',
#  '유입',
#  '명',
#  '속보',
#  '오늘',
#  '코로나',
#  '실시간',
#  '확진',
#  '자수',
#  '명',
#  '육박',
#  '속보',
#  '경북',
#  '코로나',
#  '확',
#  '진자',
#  '명',
#  '추가',
#  '발생',
#  '경산',
#  '구미',
#  '영천',
#  '칠곡',
#  '등',
#  '라면',
#  '업계',
#  '해외',
#  '매출',
#  '국내',
#  '수출',
#  '경쟁',
#  '활발',
#  '위드',
#  '코로나',
#  '도입',
#  '전망',
#  '백신',
#  '접종',
#  '인증',
#  '앱',
#  '이용',
#  '현황',
#  '분석',
#  '대구',
#  '코로나',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '총',
#  '명',
#  '사망',
#  '코로나',
#  '명',
#  '확진',
#  '요일',
#  '최',
#  '거리',
#  '두기',
#  '주',
#  '재연',
#  '종합',
#  '코로나',
#  '발생',
#  '현황',
#  '기준',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '미접',
#  '종자',
#  '예약',
#  '률',
#  '질병',
#  '청',
#  '백신',
#  '패스',
#  '위드',
#  '코로나',
#  '안전',
#  '장치',
#  '종합',
#  '코로나',
#  '발생',
#  '현황',
#  '신규',
#  '확진',
#  '명',
#  '연휴',
#  '영향',
#  '아래',
#  '코로나',
#  '신규',
#  '확진',
#  '명',
#  '명대',
#  '아래',
#  '코로나',
#  '현황',
#  '신규',
#  '확진',
#  '명',
#  '명대',
#  '아래',
#  '내년',
#  '코로나',
#  '치료',
#  '제',
#  '개발',
#  '지원',
#  '해외',
#  '예방접종',
#  '완료',
#  '자도',
#  '쿠브',
#  '통해',
#  '접종',
#  '이력',
#  '확인',
#  '가능',
#  '그래픽',
#  '코로나',
#  '확',
#  '진자',
#  '지역별',
#  '현황',
#  '국내',
#  '주요',
#  '시도',
#  '별',
#  '코로나',
#  '발생',
#  '현황',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '총',
#  '그래픽',
#  '코로나',
#  '확',
#  '진자',
#  '지역별',
#  '현황',
#  '국내',
#  '코로나',
#  '하루',
#  '확진',
#  '다시',
#  '명대',
#  '수도권',
#  '차지',
#  '그래픽',
#  '코로나',
#  '확',
#  '진자',
#  '지역별',
#  '현황',
#  '기준',
#  '국내',
#  '주요',
#  '지역',
#  '권역별',
#  '코로나',
#  '집단',
#  '감염',
#  '발생',
#  '현황',
#  '국내',
#  '코로나',
#  '하루',
#  '확진',
#  '명',
#  '이틀',
#  '명대',
#  '불안',
#  '코로나',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '네',
#  '자릿수',
#  '경북',
#  '코로나',
#  '명',
#  '확진',
#  '곳',
#  '발생',
#  '전문',
#  '대구',
#  '코로나',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '발생',
#  '속보',
#  '코로나',
#  '실시간',
#  '확진',
#  '자수',
#  '또',
#  '육박',
#  '그래픽',
#  '코로나',
#  '확',
#  '진자',
#  '지역별',
#  '현황',
#  '코로나',
#  '발생',
#  '현황',
#  '기준',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '코로나',
#  '신규',
#  '확진',
#  '명',
#  '수도권',
#  '그래픽',
#  '코로나',
#  '확',
#  '진자',
#  '지역별',
#  '현황',
#  '코로나',
#  '신규',
#  '확진',
#  '명',
#  '역대',
#  '엿새',
#  '요일',
#  '최',
#  '경신',
#  '종합',
#  '코로나',
#  '그래픽',
#  '신규',
#  '확진',
#  '이틀',
#  '증가',
#  '내년',
#  '코로나',
#  '치료',
#  '제',
#  '백신',
#  '개발',
#  '투입',
#  '국내',
#  '코로나',
#  '하루',
#  '확진',
#  '명',
#  '확산',
#  '세',
#  '수도권',
#  '차지',
#  '코로나',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '접종',
#  '완료',
#  '율',
#  '추석',
#  '방심',
#  '코로나',
#  '월요일',
#  '최',
#  '명',
#  '확진',
#  '종합',
#  '필리핀',
#  '경제',
#  '현황',
#  '및',
#  '전망',
#  '코로나',
#  '발생',
#  '현황',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '주말',
#  '두번째',
#  '규모',
#  '치명',
#  '률',
#  '주요',
#  '시도',
#  '별',
#  '코로나',
#  '발생',
#  '현황',
#  '국내',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '총',
#  '국내',
#  '코로나',
#  '현황',
#  '명',
#  '다시',
#  '명',
#  '발생',
#  '그래픽',
#  '코로나',
#  '확',
#  '진자',
#  '지역별',
#  '현황',
#  '코로나',
#  '신규',
#  '확진',
#  '명',
#  '월요일',
#  '집계',
#  '기준',
#  '역대',
#  '최',
#  '경신',
#  '종합',
#  '코로나',
#  '발생',
#  '현황',
#  '기준',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '공정위',
#  '아시아',
#  '소비자',
#  '정책',
#  '포럼',
#  '해외',
#  '직구',
#  '소비자',
#  '보호',
#  '논의',
#  '김용판',
#  '의원',
#  '국민',
#  '해외',
#  '범죄자',
#  '간다',
#  '작년',
#  '해만',
#  '범죄',
#  '건강',
#  '안전',
#  '최',
#  '우선',
#  '방탄소년단',
#  '코로나',
#  '스타디움',
#  '대면',
#  '콘서트',
#  '개',
#  '속보',
#  '코로나',
#  '실시간',
#  '확진',
#  '자수',
#  '여명',
#  '주춤',
#  '국민연금',
#  '말',
#  '수익률',
#  '해외',
#  '주식',
#  '코로나',
#  '발생',
#  '현황',
#  '기준',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '코로나',
#  '확',
#  '진자',
#  '명',
#  '일주일',
#  '연속',
#  '요일',
#  '최',
#  '거리',
#  '두기',
#  '연장',
#  '코로나',
#  '신규',
#  '확진',
#  '명',
#  '자릿수',
#  '기록',
#  '코로나',
#  '발생',
#  '현황',
#  '기준',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '기준',
#  '국내',
#  '주요',
#  '지역',
#  '권역별',
#  '코로나',
#  '집단',
#  '감염',
#  '발생',
#  '현황',
#  '코로나',
#  '현황',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '역대',
#  '두',
#  '최',
#  '기록',
#  '코로나',
#  '그래픽',
#  '신규',
#  '확진',
#  '이틀',
#  '서울시',
#  '코로나',
#  '발생',
#  '현황',
#  '코로나',
#  '발생',
#  '현황',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '유행',
#  '이후',
#  '규모',
#  '치명',
#  '률',
#  '코로나',
#  '검사',
#  '번',
#  '사이판',
#  '바다',
#  '코로나',
#  '안전',
#  '신고',
#  '개통',
#  '후',
#  '신고',
#  '내용',
#  '중',
#  '과태료',
#  '부과',
#  '건',
#  '고발',
#  '건',
#  '전문',
#  '대구',
#  '코로나',
#  '확',
#  '진자',
#  '명',
#  '외국인',
#  '집단',
#  '감염',
#  '명',
#  '전문',
#  '대구',
#  '코로나',
#  '확',
#  '진자',
#  '명',
#  '확진',
#  '그래픽',
#  '코로나',
#  '확',
#  '진자',
#  '지역별',
#  '현황',
#  '코로나',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '치명',
#  '률',
#  '베트남',
#  '외국인',
#  '직접투자',
#  '현황',
#  '반등',
#  '위',
#  '방역',
#  '정책',
#  '방향',
#  '코로나',
#  '발생',
#  '현황',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '두번째',
#  '규모',
#  '치명',
#  '률',
#  '코로나',
#  '신규',
#  '확진',
#  '명',
#  '주',
#  '요일',
#  '최',
#  '거리',
#  '두기',
#  '재연',
#  '가닥',
#  '종합',
#  '종합',
#  '코로나',
#  '확',
#  '진자',
#  '명대',
#  '지속',
#  '수도권',
#  '확산',
#  '세',
#  '코로나',
#  '신규',
#  '확진',
#  '명',
#  '역대',
#  '최',
#  '추석',
#  '후',
#  '폭풍',
#  '현실',
#  '종합',
#  '서울시',
#  '코로나',
#  '발생',
#  '현황',
#  '코로나',
#  '발생',
#  '현황',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '주일',
#  '연속',
#  '요일',
#  '최',
#  '치명',
#  '률',
#  '코로나',
#  '발생',
#  '현황',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '주말',
#  '두번째',
#  '규모',
#  '치명',
#  '률',
#  '토종',
#  '코로나',
#  '백신',
#  '치료',
#  '제',
#  '개발',
#  '쏜다',
#  '주요',
#  '시도',
#  '별',
#  '코로나',
#  '발생',
#  '현황',
#  '국내',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '총',
#  '국내',
#  '코로나',
#  '현황',
#  '명',
#  '다시',
#  '명',
#  '발생',
#  '그래픽',
#  '코로나',
#  '확',
#  '진자',
#  '지역별',
#  '현황',
#  '코로나',
#  '신규',
#  '확진',
#  '명',
#  '월요일',
#  '집계',
#  '기준',
#  '역대',
#  '최',
#  '경신',
#  '종합',
#  '코로나',
#  '발생',
#  '현황',
#  '기준',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '공정위',
#  '아시아',
#  '소비자',
#  '정책',
#  '포럼',
#  '해외',
#  '직구',
#  '소비자',
#  '보호',
#  '논의',
#  '속보',
#  '코로나',
#  '발생',
#  '현황',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '김용판',
#  '의원',
#  '국민',
#  '해외',
#  '범죄자',
#  '간다',
#  '작년',
#  '해만',
#  '범죄',
#  '김용판',
#  '의원',
#  '국민',
#  '해외',
#  '범죄자',
#  '간다',
#  '작년',
#  '해만',
#  '범죄',
#  '건강',
#  '안전',
#  '최',
#  '우선',
#  '방탄소년단',
#  '코로나',
#  '스타디움',
#  '대면',
#  '콘서트',
#  '개',
#  '속보',
#  '코로나',
#  '실시간',
#  '확진',
#  '자수',
#  '여명',
#  '주춤',
#  '국민연금',
#  '말',
#  '수익률',
#  '해외',
#  '주식',
#  '코로나',
#  '발생',
#  '현황',
#  '기준',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '속보',
#  '코로나',
#  '국내',
#  '발생',
#  '및',
#  '예방접종',
#  '현황',
#  '기준',
#  '코로나',
#  '확',
#  '진자',
#  '명',
#  '일주일',
#  '연속',
#  '요일',
#  '최',
#  '거리',
#  '두기',
#  '연장',
#  '코로나',
#  '치료',
#  '제',
#  '백신',
#  '개발',
#  '상',
#  '진행',
#  '내년',
#  '투입',
#  '코로나',
#  '신규',
#  '확진',
#  '명',
#  '자릿수',
#  '기록',
#  '코로나',
#  '발생',
#  '현황',
#  '기준',
#  '신규',
#  '확',
#  '진자',
#  '명',
#  '기준',
#  '국내',
#  '주요',
#  '지역',
#  ...]

# %%
ko = nltk.Text(doc_nouns, name="코로나뉴스_1000")
print(type(ko))
print(len(ko.tokens))
# Out:
# <class 'nltk.text.Text'>
# 9146

# %%
### 단어들의 사용 횟수 확인 - 빈도 분석
type( ko.vocab() ), ko.vocab().most_common(50)
# Out:
# (nltk.probability.FreqDist,
#  [('코로나', 843),
#   ('명', 763),
#   ('신규', 448),
#   ('현황', 440),
#   ('확', 431),
#   ('진자', 429),
#   ('발생', 366),
#   ('확진', 247),
#   ('국내', 179),
#   ('기준', 153),
#   ('명대', 153),
#   ('해외', 119),
#   ('최', 87),
#   ('수도권', 73),
#   ('속보', 68),
#   ('지역', 68),
#   ('감염', 67),
#   ('주요', 67),
#   ('백신', 60),
#   ('다시', 59),
#   ('률', 58),
#   ('이틀', 56),
#   ('종합', 51),
#   ('그래픽', 50),
#   ('접종', 48),
#   ('총', 46),
#   ('하루', 45),
#   ('집단', 43),
#   ('및', 43),
#   ('대구', 41),
#   ('별', 41),
#   ('확산', 39),
#   ('연속', 38),
#   ('예방접종', 38),
#   ('시도', 38),
#   ('전문', 36),
#   ('유입', 34),
#   ('사흘', 33),
#   ('역대', 33),
#   ('지역별', 32),
#   ('권역별', 31),
#   ('전국', 31),
#   ('성률', 31),
#   ('자릿수', 29),
#   ('등', 29),
#   ('치명', 28),
#   ('세', 28),
#   ('추가', 26),
#   ('네', 25),
#   ('추석', 24)])

# %%
### 한글에서는 따로 불용어 사전이 없어, 따로 만들거나 또는 파일로 부터 불러올 수 있다.
stop_words = ['진자','명','확','차','제','등','더','속','로','세','률','선','것','다시','이틀','시도','별','네']

new_ko = [ ]
for one_word in ko:
  if one_word not in stop_words:
    new_ko.append(one_word)

# %%
new_ko = nltk.Text(new_ko, name="해외_코로나_1000_2")

# %%
from wordcloud import WordCloud, STOPWORDS

import numpy as np
from PIL import Image

# %%
data = new_ko.vocab().most_common(1000)

# %%
wc = WordCloud(background_color='white', 
               max_words=200,
               contour_width=3, 
               contour_color="steelblue", 
               font_path=path).generate_from_frequencies(dict(data))

# %%
plt.figure(figsize=(15,8))
plt.imshow(wc)
plt.axis("off")
plt.show()
