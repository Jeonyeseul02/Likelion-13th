# %%
import pandas as pd
import seaborn as sns
import platform
from matplotlib import font_manager, rc
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ### csv 파일 불러옴

# %%
news_1 = pd.read_csv("코로나 생활지표_2021_1007_09.csv")
news_2 = pd.read_csv("코로나 주식_2021_1007_09.csv")
news_3 = pd.read_csv("코로나_2021_1007_09.csv")
news_4 = pd.read_csv("해외 코로나 현황_2021_1007_09.csv")

# %%
news_1.head()
# Out:
#     키워드                                             언론사         기사명  \
# 0   YTN  [김혜민의 이슈&피플] 우리아이 우울증인가요? 코로나19로 소아 청소년 우울 ...  2021-10-06
# 1  데이터넷                    과기정통부, '2021년 4차 산업혁명 지표' 발간  2021-10-06
# 2  경향신문          경기 연천 부대, 코로나19 집단감염 누적 46명···돌파감염 74%  2021-10-04
# 3  경향신문   "'위드코로나'는 어쩔 수 없는 ‘적과의 동침’···치명률 낮다고 안전한 질...  2021-10-05
# 4  약업신문                     코로나19가 남기는 숙제…미래 팬데믹에 대한 대비  2021-10-07
#
#                                                   날짜       URL
# 0  https://www.ytn.co.kr/_ln/0103_202110061720475386  코로나 생활지표
# 1  http://www.datanet.co.kr/news/articleView.html...  코로나 생활지표
# 2  https://www.khan.co.kr/national/national-gener...  코로나 생활지표
# 3  https://www.khan.co.kr/national/health-welfare...  코로나 생활지표
# 4  http://www.yakup.com/news/index.html?mode=view...  코로나 생활지표

# %% [markdown]
# ### 언론사 column만 가져와서 저장

# %%
news_1 = news_1[['언론사']]
news_1
# Out:
#                                                 언론사
# 0    [김혜민의 이슈&피플] 우리아이 우울증인가요? 코로나19로 소아 청소년 우울 ...
# 1                      과기정통부, '2021년 4차 산업혁명 지표' 발간
# 2            경기 연천 부대, 코로나19 집단감염 누적 46명···돌파감염 74%
# 3     "'위드코로나'는 어쩔 수 없는 ‘적과의 동침’···치명률 낮다고 안전한 질...
# 4                       코로나19가 남기는 숙제…미래 팬데믹에 대한 대비
# ..                                              ...
# 985                    경주경찰서, ‘경북청 베스트 공공안녕 정보팀’ 선정
# 986                      경주정신건강복지센터, 코로나 블루 '위로 백신'
# 987               화이자 '먹는 치료제' 임상 2상 개시…토종 개발사 '긴장'
# 988                수출 호황에 코로나19 백신접종으로 소비심리 5개월째 개선
# 989             코로나19 어제 681명 신규확진… 이틀 연속 600명대(종합)
#
# [990 rows x 1 columns]

# %%
news_2.head()
# Out:
#      키워드                                             언론사         기사명  \
# 0    MBC  [World Now] 코로나에도 돈 긁어모은 미국 슈퍼리치들..자산 '40%' 증가  2021-10-06
# 1  헤럴드경제             주식거래·부동산 보유로 낸 세금만 4조2956억원 ‘역대 최대’  2021-10-06
# 2   국민일보                 코로나에 美 ‘슈퍼리치’ 자산 40% ↑… 베이조스 1위      11면 1단
# 3   프레시안                           먹는 코로나 치료제 개발에 뒤처진 한국  2021-10-07
# 4  머니투데이             '먹는 코로나약' 충격에 맥 못추는 토종 바이오…주가 연일 급락      16면 1단
#
#                                                   날짜     URL
# 0  https://imnews.imbc.com/news/2021/world/articl...  코로나 주식
# 1  http://news.heraldcorp.com/view.php?ud=2021100...  코로나 주식
# 2  http://news.kmib.co.kr/article/view.asp?arcid=...  코로나 주식
# 3  https://www.pressian.com/pages/articles/202110...  코로나 주식
# 4  http://news.mt.co.kr/mtview.php?no=20211006154...  코로나 주식

# %%
news_2 = news_2[['언론사']]
news_3 = news_3[['언론사']]
news_4 = news_4[['언론사']]

# %%
news_2.head()
# Out:
#                                               언론사
# 0  [World Now] 코로나에도 돈 긁어모은 미국 슈퍼리치들..자산 '40%' 증가
# 1             주식거래·부동산 보유로 낸 세금만 4조2956억원 ‘역대 최대’
# 2                 코로나에 美 ‘슈퍼리치’ 자산 40% ↑… 베이조스 1위
# 3                           먹는 코로나 치료제 개발에 뒤처진 한국
# 4             '먹는 코로나약' 충격에 맥 못추는 토종 바이오…주가 연일 급락

# %%
news_3
# Out:
#                                               언론사
# 0               [속보]코로나 신규 확진자 2427명…수도권 비중 78.4%
# 1                 경기도, 코로나19 피해 관광업체 500여곳 임차료 지원
# 2    [단독] "코로나 끝나면 수요 폭발한다"…여기어때, 온라인투어 500억 투자한다
# 3                16~17세 코로나19 백신 예약률 첫날 20.8%(상보)
# 4               IMF "세계 물가상승률 가을 정점‥내년에 코로나 이전수준"
# ..                                            ...
# 985     '코로나 치료제 약발 끝?' 셀트리온 3형제, 8거래일간 시총 16조 증발
# 986     [속보] 7일 코로나19 확진자 2,427명 ... 어제보다 399명 많아
# 987                   LX하우시스, 코로나19 지원 37사 군장병 위문
# 988                  진행 요원 코로나19 확진 탐라문화제 개막공연 취소
# 989         이낙연 "평양에 '대북 특사' 보내겠다.. 北에 코로나 백신 지원"
#
# [990 rows x 1 columns]

# %%
news_4
# Out:
#                                                   언론사
# 0                 장하성 "코로나 아니면 시진핑 왔을 것"…"왕이는 어떻게 왔나"
# 1                與 "이달 말 '위드 코로나' 가야…경구 치료제 무료제공도 검토"
# 2            [코로나19 발생현황] 10월 6일 0시 기준, 신규 확진자 2,028명
# 3                                러시아 반도체 부품, LED시장 현황
# 4                          [그래픽] 코로나19 확진자 지역별 현황(6일)
# ..                                                ...
# 985           [아산 코로나 현황] 해외입국자 10대 2명 추가 확진… 누적 167명
# 986          국내 코로나19 하루 확진 447명으로 늘어, 하루 만에 다시 400명대
# 987  [속보]코로나19발생현황,신규확진자 343명..2일째 300명대 지역293명-해외50명
# 988                 [아산 코로나 현황] 해외입국자 20대 확진… 누적 163명
# 989            한상혁 "플랫폼 규제, 종합적으로 고려해 균형잡힌 정책 필요"(종합)
#
# [990 rows x 1 columns]

# %% [markdown]
# ### 변경한 data를 csv파일로 저장

# %%
news_1.to_csv("코로나_생활지표_뉴스_1000.csv", index =False)
news_2.to_csv("코로나_주식_뉴스_1000.csv", index =False)
news_3.to_csv("코로나_뉴스_1000.csv", index =False)
news_4.to_csv("해외_코로나_현황_뉴스_1000.csv", index =False)
