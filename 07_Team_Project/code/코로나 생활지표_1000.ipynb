# %%
### 나눔 고딕 설치
# !apt-get update -qq   # 설치를 업데이트 
# !apt-get install fonts-nanum* -qq  # 설치한다. fonts-nanum*
# Out:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 155047 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Selecting previously unselected package fonts-nanum-eco.
# Preparing to unpack .../fonts-nanum-eco_1.000-6_all.deb ...
# Unpacking fonts-nanum-eco (1.000-6) ...
# Selecting previously unselected package fonts-nanum-extra.
# Preparing to unpack .../fonts-nanum-extra_20170925-1_all.deb ...
# Unpacking fonts-nanum-extra (20170925-1) ...
# Selecting previously unselected package fonts-nanum-coding.
# Preparing to unpack .../fonts-nanum-coding_2.5-1_all.deb ...
# Unpacking fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-extra (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Setting up fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-eco (1.000-6) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...

# %%
import matplotlib.font_manager as fm # 폰트 관련 용도
import matplotlib.pyplot as plt      # 그래프 그리는 용도

path = '/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf' # 설치된 나눔 글꼴중 원하는 녀석의 전체
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

# 우선 fm._rebuild() 를 해주고 # 폰트 매니저 재빌드가 필요하다.
fm._rebuild()
# Out:
# NanumGothic Eco

# %%
# %matplotlib inline
import matplotlib as mpl # 기본 설정 만지는 용도
import matplotlib.pyplot as plt # 그래프 그리는 용도
import matplotlib.font_manager as fm # 폰트 관련 용도
import numpy as np

path = '/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf' # 설치된 나눔글꼴중 원하는 녀석의 전체
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

## 음수 표시되도록 설정
mpl.rcParams['axes.unicode_minus'] = False
# Out:
# NanumGothic Eco

# %%
pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.5.2-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 1.2 MB/s
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Collecting beautifulsoup4==4.6.0
#   Downloading beautifulsoup4-4.6.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 5.7 MB/s
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 30.3 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Installing collected packages: JPype1, colorama, beautifulsoup4, konlpy
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-1.3.0 beautifulsoup4-4.6.0 colorama-0.4.4 konlpy-0.5.2

# %%
import nltk
from konlpy.tag import Kkma
from konlpy.tag import Hannanum

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image

# %%
text = open("코로나_생활지표_뉴스_1000_2.csv").read()
text
# Out:
# '언론사\n[김혜민의 이슈&피플] 우리아이 우울증인가요? 코로나19로 소아 청소년 우울 ...\n"과기정통부, \'2021년 4차 산업혁명 지표\' 발간"\n"경기 연천 부대, 코로나19 집단감염 누적 46명···돌파감염 74%"\n"""\'위드코로나\'는 어쩔 수 없는 ‘적과의 동침’···치명률 낮다고 안전한 질..."\n코로나19가 남기는 숙제…미래 팬데믹에 대한 대비\n[코로나19 브리핑] 또다시 2천 명대…연휴 앞두고 촉각\n"구광모 ""재무지표 보다 고객가치 우선""…사장단 워크숍서 혁신 주문"\n한국민들 긴 코로나 잘 견딘 이유…심리방역 무려158만건\n코로나 4차 유행에도…소비심리 석달 만에 반등\n[파워인터뷰]“이달 ‘일상회복 지원위’ 출범… 위드 코로나 의견 수렴 나설...\n"대한항공, 코로나에도 실적 \'이상無\'…""항공 화물 운임 사상 최대"""\n코로나19 상황 속 공공도서관 일평균 대출 권수 38% 증가\n\'위드코로나\' 실현 확진자 조건 놓고 전문가 의견 갈려\n"정부, 주요 방역지표 \'확진자\'→\'위중증률·치명률\' 변경 방안 검토"\n"‘위드 코로나’는 작별 아닌 공존, 바이러스와 전투는 계속된다"\n“이젠 위드코로나”… 소비심리 석 달 만에 반등\n"소비자심리는 이미 \'위드코로나\', 석달만 반등..인플레압력 지속"\n"[뉴스라이브] ""거리두기 지속 힘들다""...11월 초 \'위드 코로나\'"\n"코로나 4차 대유행에도 9월 소비자 심리지수, 석 달 만에 반등"\n"부산 코로나 진정세라지만… 9월 확진 1323명, 月기준 역대 3번째"\n코로나19 상황 속 공공도서관 일평균 대출 권수 증가\n코로나 4차 유행에도 소비심리 3개월 만에 반등\n"\'위드 코로나\' 연기되나..정은경 ""내주까지 상황 보고 판단"""\n"정부 ""위드 코로나 때 사적모임·다중이용시설 거리두기 완화 검토"""\n"[기고] ‘위드 코로나’ 시대, 중환자 기준으로 방역 정책 개편해야"\n"""코로나19 이후 향후 10년 뒤, 1000만 명 여자어린이 조혼 위험에 처할수도"""\n코로나 2년... 코로나19 의료진 ‘번 아웃’ 어떻게 해결할까?\n코로나 뚫고 쾌속 질주하는 K-뷰티… 신화 다시 쓴다\n"서울시, 29일 포스트코로나 시대 청년실업 해결방안모색 연속 포럼"\n"LG생활건강, 동반성장지수 7년 연속 최우수"\n확진자 주간 발표? 코로나 유행주의보? …\'위드 코로나\' 논의 시작\n"\'위드 코로나\' 전환해도…""예전으로는 못 돌아가"""\n[장덕진의 퍼스펙티브] 내년 3월 대선까지 ‘위드 코로나’ 전환 쉽지 않을 듯\n"건강·식품·뷰티, 수출 활기에 내수 회복… 코로나 터널의 출구 보인다"\n‘코로나 확산 불구’ 대전·충남 9월 소비심리 103.7…3개월 만에 ‘반등’\n[환경칼럼] 코로나19와 고통 받는 노인들\n"[이슈진단] 코로나發 노란우산의 역설… 소상공인, \'해지·가입\' 모두 늘었다"\n씨 마른 일자리에… 직장 못 구한 청년들 ‘평생 알바’ 불안감 [연중기획 - ...\n주요 지표 고공행진 창원 국가산단에 신규 지식산업센터 공급\n먹는 코로나 치료제 1인당 90만원? 정부 “입원치료 비용 따져보면…”\n[뉴스쉽] \'위드 코로나\'로 전환 시도?…\'노 마스크\'는 아니다\n코로나 공포감도 무뎌져...전북지역 소비심리 3개월만에 \'반등\'\n[뉴스외전 코로나 브리핑] 환자 폭증‥코로나 정점은 다음주?\n"與, 정부에 \'위드코로나\' 제안…""과도한 거리두기 의존 전환해야"""\n"[사설]소상공인 줄폐업, 위드 코로나 목소리"\n[뉴스라이브] 코로나 신규 확진 1700명 대...추석 연휴 여파는\n"코로나 4차 확산 여파…정부 ""내수 불확실성 지속"""\n"경기도 생활임금, 서울시 역전... 이재명 ""최저임금 마중물"""\n국가도 신용대출을 하나요…새 투자지표로 뜨는 ESG란?\n"코로나 19로 힘든 경남지역 자영업자, 노란우산 폐업 공제금 지급 전국 4번째..."\n희생과 헌신 중심의 방역 한계…위드 코로나 앞당기는 대응체계로 전환해야\n"이통3사, 동반성장지수 ‘최우수’...“코로나19 위기 상생 극복”"\n"[지난주 의료·제약 주요이슈] 코로나19 치료제 개발 중단한 부광약품 ""효과입..."\n"[스페셜 리포트]③코로나19의 비대면 경험, 대면시대 회귀 이전 마지막 기술적..."\n"""10월 말부터 \'위드 코로나\' 가능""...국민 70% 이상 찬성"\n"경기도, ‘2022년도 생활임금’ 1만1141원 확정…10일 고시"\n국민 10명 중 7명 \'일상 속 코로나19\' 전환에 찬성\n"[기고-김상영]코로나19 팬데믹 시대, 미래에 유념해야 할 것들"\n\'한국형 위드 코로나\' 논의 본격화…우리 일상 어디서부터 바뀔까\n\'위드 코로나\' 3가지 조건…\'접종완료 80%↑·변이·사회적 합의\'\n코로나19로 찾아뵙지 못하는 부모님…영상 통화로 건강 체크하기\n"경기도 확진자 첫 700명대, 인천 140명…사회적 거리두기 4단계·\'위드 코로나..."\n코로나19 이후 경기 청소년 활동량 뚝...정신건강 상태는 ↑\n수도권 코로나 확진…1주일 새 11% 증가\n코로나19 이후 경제상황 청년일자리가 관건 (성태윤 연세대 경제학과교수)\n"[기업단신] LG생활건강, \'후 궁중 문화 캠페인\' 디지털 전개 외"\n코로나19 속 줄어든 ‘극단적 선택’…왜?\n코로나19 속 줄어든 ‘극단적 선택’…왜?\n"동반위, 삼성전자·LG생활건강 등 헬스케어 기업 \'동반성장지수\' 평가 발표"\n"다사랑복합문화예술회관, 100세시대 건강한 노후생활 실천한다"\n"[더뉴스] 정부 ""단계적 일상 회복...위드 코로나 용어 자제"""\n"강서생활, 조사하면 업그레이드!"\n\'위드 코로나\' 메시지 탓에 긴장감 풀렸나…수도권 역대 최다 확진\n\'민족 대이동\' 코 앞...\'위드 코로나\' 출발할 수 있을까?\n"직업기초능력평가 \'틴업\', 다양한 기초능력 핵심 지표로 활용"\n(영상)코로나19 대면 서비스 중심 불확실성 지속…물가 상승 압력↑\n"포스트 코로나 대비, 신뢰를 높이는 브랜드 커뮤니케이션"\n코로나 4차 유행에도 고용 개선 지속…왜?\n[국내 코로나19 현황] 21시기준 전 날보다 232명 줄어 2070명 발생\n"""토종 \'먹는\' 치료제 내년쯤…효과 중요""…코로나19 경구용 치료제 가시화"\n"[뉴스라이브] ""10명 중 6명 찬성""...\'위드 코로나\' 가기 위한 출구 전략은?"\n"한민정 정의당 대구시당위원장 ""코로나19 기억의 공간 조성 사업 부적절"""\n"[주진우 라이브] 임승관 “위드코로나든 K-방역이든 확진자는 늘어날 것, 이제..."\n위드 코로나 시대…필수된 건강관리가전\n與 의원들 “코로나19 장기화에 희생·헌신 임계점…\'위드 코로나\' 전환하자”\n코로나 근절 \'비장의 무기\' 뭐가 있나?... 치료제 개발 대웅제약 부광약품 신...\n"\'SNS대상\' 받았다는 경기硏 블로그, 수상 이후 \'경기도 주요지표\' 카테고리 운..."\n"[남부경남] 거제시, 추석 연휴 생활폐기물 처리대책 마련"\n제주 코로나19 일일 신규 확진 나흘째 한 자릿수\n\'위드 코로나\' 방역체계 전환 대선 중대변수 되나\n"강서, 주민생활 업그레이드 위한 사회조사 실시"\n"""악착같이 일해도 생계 막막… 한시 급한 위드 코로나 대책"""\n"국민절반, 일상 속 코로나 전환 2차 접종 70%"\n"가전업계, 위드 코로나 및 원자재값·해운 운임 상승에 하반기 전망 ‘흐림’"\n"\'먹고, 뿌리는\' 코로나19 치료제…개발 박차"\n[이병도의 時代架橋] 서민생활 악화 vs 경제위기 도화선…雪上加霜\n"위드코로나, 전 국민 70% 이상 2차 접종해야 가능"\n[16일 서울 관악구 소식] 생활문화 프로그램 \'관악아지트 들락날락\' 운영 등\n"양천구, 전국 기초자치단체 ESG 평가지수서 \'종합 1위\'"\n코로나19 신규확진자 1천700∼800명대 예상…오늘부터 거리두기 2주 재연장\n"LG생활건강, 7년 연속 동반성장지수 최우수 획득"\n코로나19 이후 경기 청소년 활동량 뚝...정신건강 상태는 ↑\n경기도 2022년도 생활임금 1만 1141원 확정 고 ...

# %%
print(STOPWORDS)
# Out:
# {'the', 'other', 'was', 'cannot', "she'd", 'does', 'hers', 'more', "you'll", 'www', 'who', "they'll", "who's", 'shall', 'if', 'very', "why's", 'before', 'where', 'whom', 'also', 'should', 'some', 'but', 'so', 'being', 'about', 'by', 'at', 'get', 'of', 'can', 'between', 'or', 'yours', 'only', "he's", 'through', 'did', 'my', 'ours', 'with', 'from', 'both', 'it', "don't", 'out', 'however', 'he', 'her', "here's", 'few', 'nor', 'otherwise', 'until', "it's", "we'll", "let's", 'here', "i've", 'have', 'any', 'down', 'they', "isn't", 'such', 'r', 'all', "hadn't", 'has', 'once', 'which', 'an', "we're", "you'd", "they're", 'when', "she's", 'why', "they'd", 'during', 'had', 'our', 'me', 'myself', 'am', 'there', 'these', "we've", 'be', "that's", 'ourselves', 'most', "i'd", 'not', "couldn't", 'were', 'your', 'while', 'is', 'for', "hasn't", 'we', 'like', "shouldn't", 'to', 'could', "wouldn't", 'on', 'under', 'itself', "you're", 'their', "you've", 'them', "where's", 'in', 'him', 'are', 'into', 'as', 'having', 'his', 'just', 'each', 'against', "aren't", 'how', 'i', "can't", "there's", "shan't", 'then', 'do', "won't", "didn't", "weren't", 'below', 'those', 'ever', 'since', 'ought', "they've", 'that', 'yourselves', 'too', "doesn't", "he'd", 'because', "she'll", 'themselves', 'she', "mustn't", 'http', 'off', 'this', "he'll", 'its', 'same', 'over', "when's", 'himself', 'doing', 'than', 'above', 'up', "i'll", "i'm", 'else', 'again', 'no', "we'd", 'what', 'would', 'you', 'herself', 'further', 'theirs', 'been', 'yourself', 'a', 'and', 'com', "what's", 'after', "how's", 'k', "wasn't", "haven't", 'own'}

# %%
from konlpy.tag import Okt   ### Okt
t = Okt()

#from konlpy.tag import Kkma  ### Okt
#t = Kkma()
doc_nouns = t.nouns(text)
print( len( doc_nouns ) )
doc_nouns
# Out:
# 8478
# ['언론사',
#  '김혜민',
#  '이슈',
#  '피플',
#  '우리',
#  '아이',
#  '우울증',
#  '코로나',
#  '로',
#  '소아',
#  '청소년',
#  '우울',
#  '과',
#  '정통부',
#  '차',
#  '산업혁명',
#  '지표',
#  '발간',
#  '경기',
#  '연천',
#  '부대',
#  '코로나',
#  '집단',
#  '감염',
#  '누적',
#  '명',
#  '돌파',
#  '감염',
#  '위드',
#  '코로나',
#  '수',
#  '적',
#  '동침',
#  '치명',
#  '률',
#  '질',
#  '코로나',
#  '숙제',
#  '미래',
#  '팬데믹',
#  '대한',
#  '대비',
#  '코로나',
#  '브리핑',
#  '명대',
#  '연휴',
#  '촉각',
#  '구광모',
#  '재무',
#  '지표',
#  '고객',
#  '가치',
#  '우선',
#  '장단',
#  '워크숍',
#  '혁신',
#  '주문',
#  '국민',
#  '코로나',
#  '이유',
#  '심리',
#  '방역',
#  '무려',
#  '코로나',
#  '차',
#  '유행',
#  '소비',
#  '심리',
#  '달',
#  '반등',
#  '파워',
#  '인터뷰',
#  '달',
#  '일상',
#  '회복',
#  '지원',
#  '위',
#  '출범',
#  '위드',
#  '코로나',
#  '의견',
#  '수렴',
#  '대한항공',
#  '코로나',
#  '실적',
#  '이상',
#  '항공',
#  '화물',
#  '운임',
#  '사상',
#  '최대',
#  '코로나',
#  '상황',
#  '속',
#  '도서관',
#  '평균',
#  '대출',
#  '권수',
#  '증가',
#  '위드',
#  '코로나',
#  '실현',
#  '확',
#  '진자',
#  '조건',
#  '전문가',
#  '의견',
#  '정부',
#  '주요',
#  '방역',
#  '지표',
#  '확',
#  '진자',
#  '위중',
#  '증률',
#  '치명',
#  '률',
#  '변경',
#  '방안',
#  '검토',
#  '위드',
#  '코로나',
#  '작별',
#  '공존',
#  '바이러스',
#  '전투',
#  '계속',
#  '젠',
#  '위드',
#  '코로나',
#  '소비',
#  '심리',
#  '석',
#  '달',
#  '반등',
#  '소비자',
#  '심리',
#  '위드',
#  '코로나',
#  '달',
#  '반등',
#  '인플레',
#  '압력',
#  '지속',
#  '뉴스라이브',
#  '거리',
#  '두기',
#  '지속',
#  '초',
#  '위드',
#  '코로나',
#  '코로나',
#  '차',
#  '대유행',
#  '소비자',
#  '심리',
#  '지수',
#  '석',
#  '달',
#  '반등',
#  '부산',
#  '코로나',
#  '진정',
#  '세라',
#  '확진',
#  '명',
#  '기준',
#  '역대',
#  '코로나',
#  '상황',
#  '속',
#  '도서관',
#  '평균',
#  '대출',
#  '권수',
#  '증가',
#  '코로나',
#  '차',
#  '유행',
#  '소비',
#  '심리',
#  '개월',
#  '반등',
#  '위드',
#  '코로나',
#  '연기',
#  '정은경',
#  '내주',
#  '상황',
#  '보고',
#  '판단',
#  '정부',
#  '위드',
#  '코로나',
#  '때',
#  '사적',
#  '모임',
#  '다중',
#  '이용',
#  '시설',
#  '거리',
#  '두기',
#  '완화',
#  '검토',
#  '기고',
#  '위드',
#  '코로나',
#  '시대',
#  '중환자',
#  '기준',
#  '방역',
#  '정책',
#  '개편',
#  '코로나',
#  '이후',
#  '향후',
#  '뒤',
#  '명',
#  '여자',
#  '어린이',
#  '혼',
#  '위험',
#  '처',
#  '코로나',
#  '코로나',
#  '의료',
#  '진',
#  '번',
#  '아웃',
#  '해결',
#  '코로나',
#  '쾌속',
#  '질주',
#  '뷰티',
#  '신화',
#  '다시',
#  '서울시',
#  '포스트',
#  '코로나',
#  '시대',
#  '청년실업',
#  '해결',
#  '방안',
#  '모색',
#  '연속',
#  '포럼',
#  '생활',
#  '건강',
#  '동반성',
#  '장지수',
#  '연속',
#  '최우수',
#  '확',
#  '진자',
#  '주간',
#  '발표',
#  '코로나',
#  '유행',
#  '주의보',
#  '위드',
#  '코로나',
#  '논의',
#  '시작',
#  '위드',
#  '코로나',
#  '전환',
#  '예전',
#  '못',
#  '장덕진',
#  '퍼스',
#  '펙티브',
#  '내년',
#  '대선',
#  '위드',
#  '코로나',
#  '전환',
#  '듯',
#  '건강',
#  '식품',
#  '뷰티',
#  '수출',
#  '활기',
#  '수',
#  '회복',
#  '코로나',
#  '터널',
#  '출구',
#  '코로나',
#  '확산',
#  '불구',
#  '대전',
#  '충남',
#  '소비',
#  '심리',
#  '개월',
#  '반등',
#  '환경',
#  '칼럼',
#  '코로나',
#  '고통',
#  '노',
#  '이슈',
#  '진단',
#  '코로나',
#  '우산',
#  '역설',
#  '소상',
#  '공인',
#  '해지',
#  '가입',
#  '모두',
#  '씨',
#  '일자리',
#  '직장',
#  '못',
#  '구한',
#  '청년',
#  '평생',
#  '알바',
#  '불안감',
#  '연중',
#  '기획',
#  '주요',
#  '지표',
#  '고공',
#  '행진',
#  '창원',
#  '국가',
#  '산단',
#  '신규',
#  '지식',
#  '산업',
#  '센터',
#  '공급',
#  '코로나',
#  '치료',
#  '제',
#  '정부',
#  '입원',
#  '치료',
#  '비용',
#  '뉴스',
#  '위드',
#  '코로나',
#  '로',
#  '전환',
#  '시도',
#  '노',
#  '마스크',
#  '코로나',
#  '공포',
#  '무뎌져',
#  '전북',
#  '지역',
#  '소비',
#  '심리',
#  '개월',
#  '반등',
#  '뉴스',
#  '외전',
#  '코로나',
#  '브리핑',
#  '환자',
#  '폭증',
#  '코로나',
#  '정점',
#  '다음주',
#  '정부',
#  '위드',
#  '코로나',
#  '제안',
#  '과도',
#  '거리',
#  '두기',
#  '의존',
#  '전환',
#  '사설',
#  '소상',
#  '공인',
#  '줄',
#  '폐업',
#  '위드',
#  '코로나',
#  '목소리',
#  '뉴스라이브',
#  '코로나',
#  '신규',
#  '확진',
#  '명',
#  '추석',
#  '연휴',
#  '여파',
#  '코로나',
#  '차',
#  '확산',
#  '여파',
#  '정부',
#  '수',
#  '불확실',
#  '지속',
#  '경기도',
#  '생활임금',
#  '서울시',
#  '역전',
#  '이재명',
#  '최저임금',
#  '마중',
#  '물',
#  '국가',
#  '신용',
#  '대출',
#  '하나요',
#  '새',
#  '투자',
#  '지표',
#  '란',
#  '코로나',
#  '로',
#  '경남',
#  '지역',
#  '자영',
#  '업자',
#  '우산',
#  '폐업',
#  '공제',
#  '금',
#  '지급',
#  '전국',
#  '희생',
#  '헌신',
#  '중심',
#  '방역',
#  '한계',
#  '위드',
#  '코로나',
#  '대응',
#  '체계',
#  '전환',
#  '이통',
#  '사',
#  '동반성',
#  '장지수',
#  '최우수',
#  '코로나',
#  '위기',
#  '상생',
#  '극복',
#  '지난주',
#  '의료',
#  '제약',
#  '이슈',
#  '코로나',
#  '치료',
#  '제',
#  '개발',
#  '중단',
#  '부광약품',
#  '효과',
#  '입',
#  '스페셜',
#  '리포트',
#  '코로나',
#  '의',
#  '비대',
#  '경험',
#  '대면',
#  '시대',
#  '회귀',
#  '이전',
#  '마지막',
#  '기술',
#  '말',
#  '위드',
#  '코로나',
#  '가능',
#  '국민',
#  '이상',
#  '찬성',
#  '경기도',
#  '생활임금',
#  '확정',
#  '고시',
#  '국민',
#  '명',
#  '중',
#  '명',
#  '일상',
#  '속',
#  '코로나',
#  '전환',
#  '찬성',
#  '기고',
#  '김상영',
#  '코로나',
#  '팬데믹',
#  '시대',
#  '미래',
#  '유념',
#  '것',
#  '한국',
#  '위드',
#  '코로나',
#  '논의',
#  '본격',
#  '우리',
#  '일상',
#  '부터',
#  '위드',
#  '코로나',
#  '가지',
#  '조건',
#  '접종',
#  '완료',
#  '변',
#  '사회',
#  '합의',
#  '코로나',
#  '로',
#  '부모님',
#  '영상',
#  '통화',
#  '건강',
#  '체크',
#  '경기도',
#  '확',
#  '진자',
#  '첫',
#  '명대',
#  '인천',
#  '명',
#  '사회',
#  '거리',
#  '두기',
#  '단계',
#  '위드',
#  '코로나',
#  '코로나',
#  '이후',
#  '경기',
#  '청소년',
#  '활동',
#  '량',
#  '뚝',
#  '정신건강',
#  '상태',
#  '수도권',
#  '코로나',
#  '확진',
#  '주일',
#  '새',
#  '증가',
#  '코로나',
#  '이후',
#  '경제',
#  '상황',
#  '청년',
#  '일자리',
#  '관건',
#  '성태',
#  '윤',
#  '연세대',
#  '경제학',
#  '교수',
#  '기업',
#  '단신',
#  '생활',
#  '건강',
#  '후',
#  '궁',
#  '문화',
#  '캠페인',
#  '디지털',
#  '전개',
#  '외',
#  '코로나',
#  '속',
#  '극단',
#  '선택',
#  '왜',
#  '코로나',
#  '속',
#  '극단',
#  '선택',
#  '왜',
#  '동반',
#  '위',
#  '삼성',
#  '전자',
#  '생활',
#  '건강',
#  '등',
#  '헬',
#  '스케',
#  '기업',
#  '동반성',
#  '장지수',
#  '평가',
#  '발표',
#  '다사',
#  '복합',
#  '문화',
#  '예술',
#  '회관',
#  '시대',
#  '노후',
#  '생활',
#  '실천',
#  '더',
#  '뉴스',
#  '정부',
#  '단계',
#  '일상',
#  '회복',
#  '위드',
#  '코로나',
#  '용어',
#  '자제',
#  '강서',
#  '생활',
#  '조사',
#  '업그레이드',
#  '위드',
#  '코로나',
#  '메시지',
#  '탓',
#  '긴장감',
#  '수도권',
#  '역대',
#  '최',
#  '확진',
#  '민족',
#  '대이동',
#  '코',
#  '앞',
#  '위드',
#  '코로나',
#  '출발',
#  '수',
#  '직업',
#  '초능력',
#  '평가',
#  '틴업',
#  '초능력',
#  '핵심',
#  '지표',
#  '활용',
#  '영상',
#  '코로나',
#  '대면',
#  '서비스',
#  '중심',
#  '불확실',
#  '지속',
#  '물가',
#  '상승',
#  '압력',
#  '포스트',
#  '코로나',
#  '대비',
#  '신뢰',
#  '브랜드',
#  '커뮤니케이션',
#  '코로나',
#  '차',
#  '유행',
#  '고용',
#  '개선',
#  '지속',
#  '왜',
#  '국내',
#  '코로나',
#  '현황',
#  '전',
#  '날',
#  '명',
#  '명',
#  '발생',
#  '토종',
#  '치료',
#  '제',
#  '내년',
#  '효과',
#  '중요',
#  '코로나',
#  '용',
#  '치료',
#  '제',
#  '가시',
#  '뉴스라이브',
#  '명',
#  '중',
#  '명',
#  '찬성',
#  '위드',
#  '코로나',
#  '가기',
#  '위',
#  '출구',
#  '전략',
#  '한민정',
#  '정의당',
#  '대구시',
#  '위원장',
#  '코로나',
#  '기억',
#  '공간',
#  '조성',
#  '사업',
#  '부적절',
#  '주진우',
#  '라이브',
#  '임',
#  '승관',
#  '위드',
#  '코로나',
#  '방역',
#  '확',
#  '진자',
#  '것',
#  '이제',
#  '위드',
#  '코로나',
#  '시대',
#  '필수',
#  '건강',
#  '관리',
#  '가전',
#  '의원',
#  '코로나',
#  '장기',
#  '희생',
#  '헌신',
#  '임계점',
#  '위드',
#  '코로나',
#  '전환',
#  '코로나',
#  '근절',
#  '비장',
#  '무기',
#  '뭐',
#  '치료',
#  '제',
#  '개발',
#  '대웅제약',
#  '부광약품',
#  '신',
#  '대상',
#  '경기',
#  '블로그',
#  '수상',
#  '이후',
#  '경기도',
#  '지표',
#  '카테고리',
#  '운',
#  '남부',
#  '경남',
#  '거제시',
#  '추석',
#  '연휴',
#  '생활',
#  '폐기물',
#  '처리',
#  '대책',
#  '마련',
#  '제주',
#  '코로나',
#  '일일',
#  '신규',
#  '확진',
#  '나흘',
#  '자릿수',
#  '위드',
#  '코로나',
#  '방역',
#  '체계',
#  '전환',
#  '대선',
#  '중대',
#  '변수',
#  '강서',
#  '주민',
#  '생활',
#  '업그레이드',
#  '위',
#  '사회',
#  '조사',
#  '실시',
#  '일해',
#  '생계',
#  '막막',
#  '한시',
#  '위드',
#  '코로나',
#  '대책',
#  '국민',
#  '절반',
#  '일상',
#  '속',
#  '코로나',
#  '전환',
#  '차',
#  '접종',
#  '가전',
#  '업계',
#  '위드',
#  '코로나',
#  '및',
#  '원자재',
#  '값',
#  '해운',
#  '운임',
#  '상승',
#  '하반기',
#  '전망',
#  '코로나',
#  '치료',
#  '제',
#  '개발',
#  '박차',
#  '이병도',
#  '서민',
#  '생활',
#  '악화',
#  '경제위기',
#  '도화선',
#  '위드',
#  '코로나',
#  '전',
#  '국민',
#  '이상',
#  '차',
#  '접종',
#  '가능',
#  '서울',
#  '관악구',
#  '소식',
#  '생활',
#  '문화',
#  '프로그램',
#  '관악',
#  '아지트',
#  '들락날락',
#  '운영',
#  '등',
#  '양천구',
#  '전국',
#  '기초',
#  '자치',
#  '단체',
#  '평가',
#  '지수',
#  '종합',
#  '위',
#  '코로나',
#  '신규',
#  '확',
#  '진자',
#  '명대',
#  '예상',
#  '오늘',
#  '거리',
#  '두기',
#  '주',
#  '재연',
#  '생활',
#  '건강',
#  '연속',
#  '동반성',
#  '장지수',
#  '최우수',
#  '획득',
#  '코로나',
#  '이후',
#  '경기',
#  '청소년',
#  '활동',
#  '량',
#  '뚝',
#  '정신건강',
#  '상태',
#  '경기도',
#  '생활임금',
#  '확정',
#  '고시',
#  '수도권',
#  '코로나',
#  '확진',
#  '주일',
#  '새',
#  '증가',
#  '코로나',
#  '이후',
#  '경제',
#  '상황',
#  '청년',
#  '일자리',
#  '관건',
#  '성태',
#  '윤',
#  '연세대',
#  '경제학',
#  '교수',
#  '기업',
#  '단신',
#  '생활',
#  '건강',
#  '후',
#  '궁',
#  '문화',
#  '캠페인',
#  '디지털',
#  '전개',
#  '외',
#  '코로나',
#  '속',
#  '극단',
#  '선택',
#  '왜',
#  '코로나',
#  '속',
#  '극단',
#  '선택',
#  '왜',
#  '동반',
#  '위',
#  '삼성',
#  '전자',
#  '생활',
#  '건강',
#  '등',
#  '헬',
#  '스케',
#  '기업',
#  '동반성',
#  '장지수',
#  '평가',
#  '발표',
#  '다사',
#  '복합',
#  '문화',
#  '예술',
#  '회관',
#  '시대',
#  '노후',
#  '생활',
#  '실천',
#  '코로나',
#  '이후',
#  '경제',
#  '상황',
#  '청년',
#  '일자리',
#  '관건',
#  '성태',
#  '윤',
#  '연세대',
#  '경제학',
#  '교수',
#  '기업',
#  '단신',
#  '생활',
#  '건강',
#  '후',
#  '궁',
#  '문화',
#  '캠페인',
#  '디지털',
#  '전개',
#  '외',
#  '코로나',
#  '속',
#  '극단',
#  '선택',
#  '왜',
#  '생활',
#  '건강',
#  '업계',
#  '최초',
#  '동반성',
#  '장지수',
#  '연속',
#  '최우수',
#  '선정',
#  '코로나',
#  '속',
#  '극단',
#  '선택',
#  '왜',
#  '동반',
#  '위',
#  '삼성',
#  '전자',
#  '생활',
#  '건강',
#  '등',
#  '헬',
#  '스케',
#  '기업',
#  ...]

# %%
ko = nltk.Text(doc_nouns, name="코로나생활지표_1000")
print(type(ko))
print(len(ko.tokens))
# Out:
# <class 'nltk.text.Text'>
# 8478

# %%
### 단어들의 사용 횟수 확인 - 빈도 분석
type( ko.vocab() ), ko.vocab().most_common(50)
# Out:
# (nltk.probability.FreqDist,
#  [('코로나', 655),
#   ('명', 142),
#   ('확', 113),
#   ('진자', 107),
#   ('심리', 92),
#   ('발생', 74),
#   ('지표', 70),
#   ('감염', 70),
#   ('위드', 68),
#   ('현황', 68),
#   ('차', 67),
#   ('소비', 67),
#   ('생활', 66),
#   ('신규', 61),
#   ('확산', 60),
#   ('확진', 53),
#   ('명대', 47),
#   ('치료', 47),
#   ('접종', 46),
#   ('거리', 44),
#   ('연속', 44),
#   ('두기', 43),
#   ('전국', 43),
#   ('회복', 41),
#   ('이후', 41),
#   ('제', 41),
#   ('소비자', 40),
#   ('건강', 39),
#   ('위', 38),
#   ('백신', 37),
#   ('집단', 36),
#   ('개월', 36),
#   ('정부', 35),
#   ('세', 35),
#   ('극복', 34),
#   ('유행', 32),
#   ('대유행', 32),
#   ('지수', 29),
#   ('상승', 29),
#   ('사회', 28),
#   ('경제', 28),
#   ('방역', 27),
#   ('지역', 27),
#   ('개발', 27),
#   ('등', 27),
#   ('더', 27),
#   ('국내', 27),
#   ('속', 26),
#   ('시대', 26),
#   ('단계', 26)])

# %%
### 한글에서는 따로 불용어 사전이 없어, 따로 만들거나 또는 파일로 부터 불러올 수 있다.
stop_words = ['진자','명','확','차','제','등','더','속','로','세','률','선','것']

new_ko = [ ]
for one_word in ko:
  if one_word not in stop_words:
    new_ko.append(one_word)

# %%
new_ko = nltk.Text(new_ko, name="코로나_생활지표_1000_2")

# %%
from wordcloud import WordCloud, STOPWORDS

import numpy as np
from PIL import Image

# %%
data = new_ko.vocab().most_common(1000)

# %%
wc = WordCloud(background_color='white', 
               max_words=200,
               contour_width=3, 
               contour_color="steelblue", 
               font_path=path).generate_from_frequencies(dict(data))

# %%
plt.figure(figsize=(15,8))
plt.imshow(wc)
plt.axis("off")
plt.show()
