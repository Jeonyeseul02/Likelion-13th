# %%
### 나눔 고딕 설치
# !apt-get update -qq   # 설치를 업데이트 
# !apt-get install fonts-nanum* -qq  # 설치한다. fonts-nanum*
# Out:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 155047 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Selecting previously unselected package fonts-nanum-eco.
# Preparing to unpack .../fonts-nanum-eco_1.000-6_all.deb ...
# Unpacking fonts-nanum-eco (1.000-6) ...
# Selecting previously unselected package fonts-nanum-extra.
# Preparing to unpack .../fonts-nanum-extra_20170925-1_all.deb ...
# Unpacking fonts-nanum-extra (20170925-1) ...
# Selecting previously unselected package fonts-nanum-coding.
# Preparing to unpack .../fonts-nanum-coding_2.5-1_all.deb ...
# Unpacking fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-extra (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Setting up fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-eco (1.000-6) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...

# %%
import matplotlib.font_manager as fm # 폰트 관련 용도
import matplotlib.pyplot as plt      # 그래프 그리는 용도

path = '/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf' # 설치된 나눔 글꼴중 원하는 녀석의 전체
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

# 우선 fm._rebuild() 를 해주고 # 폰트 매니저 재빌드가 필요하다.
fm._rebuild()
# Out:
# NanumGothic Eco

# %%
# %matplotlib inline
import matplotlib as mpl # 기본 설정 만지는 용도
import matplotlib.pyplot as plt # 그래프 그리는 용도
import matplotlib.font_manager as fm # 폰트 관련 용도
import numpy as np

path = '/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf' # 설치된 나눔글꼴중 원하는 녀석의 전체
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

## 음수 표시되도록 설정
mpl.rcParams['axes.unicode_minus'] = False
# Out:
# NanumGothic Eco

# %%
pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.5.2-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 71.5 MB/s
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 54.5 MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Collecting beautifulsoup4==4.6.0
#   Downloading beautifulsoup4-4.6.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 5.5 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Installing collected packages: JPype1, colorama, beautifulsoup4, konlpy
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-1.3.0 beautifulsoup4-4.6.0 colorama-0.4.4 konlpy-0.5.2

# %%
import nltk
from konlpy.tag import Kkma
from konlpy.tag import Hannanum

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image

# %%
text = open("코로나_주식_뉴스_1000_2.csv").read()
text
# Out:
# '언론사\n[World Now] 코로나에도 돈 긁어모은 미국 슈퍼리치들..자산 \'40%\' 증가\n주식거래·부동산 보유로 낸 세금만 4조2956억원 ‘역대 최대’\n코로나에 美 ‘슈퍼리치’ 자산 40% ↑… 베이조스 1위\n먹는 코로나 치료제 개발에 뒤처진 한국\n\'먹는 코로나약\' 충격에 맥 못추는 토종 바이오…주가 연일 급락\n"글로벌프랜차이즈협의회, 경기도주식회사와 배달특급 활성화 협약"\n"고승범 ""주식 양도세 문제 기재부와 협의할 것"""\n[책] 주식 고수가 말하는 ‘ETF로 연 40% 수익 내는법’\n큰손들 \'최애 주식\'부터 루키株까지…\'투자 눈높이\' 올라간다\n"홍남기 ""장기보유 주식에 세제 혜택, 자금 동결 우려"""\n\'악재 겹겹\' 3000 깨진 코스피…살아남은 건 \'위드 코로나\'\n"차백신연구소 ""코로나 백신 안전·신뢰성 높일 것"""\n"[동부경남] 김해시, 위드 코로나 시대 새 관광지도 제작\xa0"\n"""혁신조달 이노비즈기업, 코로나 위기에도 20% 넘는 성장률"""\n큰손들 \'최애 주식\'부터 루키株까지…\'투자 눈높이\' 올라간다\n"""우리도 해외주식 한다""…대형 증권사 쫓는 중형사들"\n[친절한 경제] 주식 \'물타기\' 해도 될까? 쌓여있는 악재 체크하세요\n"김난도 ""위드 코로나 시대는 거대한 갈림길...도약하거나 위축되거나"""\n"휴온스블러썸, 연내 주식거래 재개...정상화 돌입"\n[2021국감]매일 1100억원 상당 사기 발생…코로나 이후 급증\n"먹는 코로나 치료제 개발, 국내 제약주에 직격탄"\n"[2021 국감] ""주식 양도세 과도…개인엔 기울어진 운동장"""\n"[생생경제] 코로나 시대가 가져온 업무 환경의 변화, 비대면 협업툴이란"\n"LG전자 주식 매수의견 유지, ""고급가전 수요는 코로나19 뒤에도 지속"""\n"베트남증시, 9월까지 주식계좌 96만여개 신규 개설…이전 3년치보다 많아"\n"""주식·채권 같이 보면 시장의 판단은 \'스태그\'보단 \'인플레\'"""\n"[채권마감] 지옥문 열리다…10년금리 3년만최고, 코로나 발발이후 최대폭 급등"\n"LG생활건강 주식 매수의견 유지, “화장품 브랜드가치 계속 지켜”"\n5일 주식시장 급락했던 4가지 이유\n\'환율·유가·물가\' 삼중고 가중…코로나 경제회복 \'발목\'\n"""섣부른 주식 확대 경계···원자재·리츠 담고 金은 축소해야"""\n"[주식] 한국비엔씨, 오전 장 급등 보여 3만원선 재돌파"\n역대급 유동성에 증시는 호황…주식 가치는 \'털썩\'\n[투자의 창] \'코로나주의보\'는 현재 진행형\n[GAM] 골드만삭스가 선정한 기시다 체제 속 급등할 일본 주식 6선\n"국산 3D 프린터 개발사 주식회사 다락방, \'크리메이커 메탈 V2\' 출시"\n[로로쌤의 원포인트 투자] 위드코로나 시대 오면 \'K-뷰티\' 꽃 필까\n"(주)까를로, 서울시립수락양로원에 코로나 방역 마스크 후원"\n"코로나19로 문 닫은 서산 베니키아호텔 새 주인 맞아...""재개장 기대돼"""\n"美 X세대, 코로나19 팬데믹 동안 자산 50% 늘었다"\n"직장인, 월급 12일 후 ‘월급고개’..코로나 장기화에 앞당겨졌다"\n코로나 약발 끝난 제약·바이오지수 올들어 30% 급락…가치 입증해야\n주식회사 문창 대표이사 문성호 농축산물 가격안정기금 500만원 기탁\n"[주식] 제주항공 주가 상승, \'위드코로나\'로 여행·항공주 미소"\n코로나19 장기화에 정부사칭 스팸급증…절반 이상 불법대출광고\n"“변동성 높은 10월, 경기회복·방어주 함께 사라”[해외주식 인싸이트]"\n480만원짜리 명품백 대신 \'이 주식\' 샀다면 25배 이익 \'돈방석\'\n"증시 둔화에 엇갈린 재테크 심리, 주식 꺾이고 부동산 상승세"\n[누이떠] 주식 출렁이니 리츠 뜬다… 하반기 주목할 해외 리츠는\n[기고] 해외취업은 주식과 같다?\n[스톡톡스]3000선 붕괴…“신흥국 코로나 정점 통과 여부 주목”\n"[서학개미 뭐샀나] “위기는 기회다”…서학개미, 기술주·홍콩주식 러브콜"\n"상승동력 잃은 코스피, 코로나 이후 분기 기준으로 첫 하락"\n알약 코로나 치료제 나오나···뉴욕 증시가 들썩였다\n"신풍제약, 주가 \'맑음\'…김 총리 ""국내 코로나 치료제 상황 검토"""\n[데스크칼럼] 코로나 청구서\n"주식회사 지투지, 화성시에 저자극 살균제 후원물품 전달"\n"TDF, 은퇴 시점서 주식 비중 줄이는 이유는"\n"기아 주식 매수의견 유지, ""우호적 환율효과로 생산차질 영향 방어"""\n"남양유업 코로나19 악용, 식약처 \'대기업 봐주기\' 수수방관 의혹 제기"\n"""잠을 못 잤다"" 주식전문가 \'스트릿우먼파이터\' 보고 화들짝 놀란 이유"\n머크 코로나19 치료제로 뉴욕증시 일제히 상승\n\'오징어 게임\' 최후의 승자가 받는 \'상금 456억\' 될 주식 찾는다면…\n"""신세계, \'위드 코로나\'로 소비 회복될 듯""...대신증권"\n"인플레헤지 수익내려면... 요지 부동산과 황금, 반도체 주식 사라"\n美 매파 Fed 인사 두 명 낙마‥부적절한 주식 거래 연루 \'후폭풍\'\n"[더벨]""E보다 S·G 무게...선진국 주식 중심 포트폴리오 추천"""\n"[big story]부자 꿈꾸는 MZ세대, 장외주식에 꽂힌 이유는"\n코로나 백신접종 4000만명 초읽기…수혜주는\n"""\'코로나 여파\' 전기료 고액체납자 633명…요금 112억 달해"""\n주식시장 와르르...제약바이오주 하루새 시총 18조 증발\n"\'패닉\' 중국주식, 중학개미들은 어찌하오리까"\n코로나 휴업 서산 베니키아호텔 새 주인 맞아\n"[주식고수] ""주식은 사냥 아닌 농사""...\'주식농부\' 박영옥의 투자관"\n"[여의도 주식왕 강철주식] AI vs AI 시스템 대결, 새 시즌 개막!"\n"주식 반대매매 일평균 85억, 연중 최대…금감원 ‘빚투폭탄’ 경고"\n[중국 마이종목] 美 코로나 먹는 치료제 발표에 푸싱의약 주가 급락\n"모건스탠리, 잇단 \'빅딜\'로 1위 지켜…KB證, 주식·채권발행 \'2관왕\'"\n놓치지 말고 살펴봐야 할 주식은? 위드 코로나 시대 투자 전략\n"[주식초고수는 지금] 3,000선 무너진 코스피, 한국비엔씨 \'저가매수\'···2차..."\n[주식] 현대바이오 주가 급락\n[금융 돋보기] 4분기 주식투자 전략\n[현장에서]동학개미들이 `주식 양도세` 반대하는 이유\n코로나19 경구용 치료제 개발..증시 ‘게임 체인저’되나\n"다가오는 위드 코로나…""급반등 기대되는 OO주 담아라"""\n"부광약품, 코로나19 치료제 레보비르 효과 미입증…사실상 개발 포기"\n주식·주택 ‘청년 빚투’ 무섭게 늘어… 가계부채의 26.9% 차지\n코로나19로 7월 여행사 생산지수 추락…인터넷쇼핑 최대 호황\n"서초구, 전국 최초 \'서초여성일자리주식회사\' 1일 출범"\n전셋값 폭등·주식 열풍에…‘청년 빚’ 크게 늘었다\n"하이트진로 주식 매수의견 유지, “거리두기 주류업황도 대폭 회복”"\n[누이떠] 5000원으로 ‘종로 한복판’ SK서린빌딩 주인된다… 주식 대안으로 ...\n\'상한가 종목\'에 혹한 4050…주식리딩방 피해금 벌써 170억\n韓 주식시장 먹구름…코스피 6개월 만에 3000선 붕괴\xa0\n발표 하루 전 주식펀드로 갈아탄 연준 \'넘버2\'\n주식 \'빚투\' 반대매매 한달새 2배 급증…연중 최고치 갱신\n"국민 2명 중 1명 ""코로나 이후 \'읽기 시간\' 증가"""\n[Mint] NFL을 아마존에서 본다고? 코로나가 흔든 스포츠 산업\n"[GAM] ""열 살부터 주식에 빠졌어요"" 유럽 밀레니얼의 성공 철칙"\n‘영끌’ 부동산·주식 투자 막는다…홍남기 “최대한 억제”(종합)\n주식시장 와르르...제약바이오주 하루새 시총 18조 증발\n"\'패닉\' 중국주식, 중학개미들은 어찌하오리까"\n코로나 휴업 서산 베니키아호텔 새 주인 맞아\n"[주식고수] ""주식은 사냥 아닌 농사""...\'주식농부\' 박영옥의 투자관"\n"[여의도 주식왕 강철주식] AI vs AI 시스템 대결, 새 시즌 개막!"\n코로나로 문 닫은 서산 베니키아호텔 새 주인 맞아\n"주식 반대매매 일평균 85억, 연중 최대…금감원 ‘빚투폭탄’ 경고 ...

# %%
print(STOPWORDS)
# Out:
# {"won't", 'was', 'since', "they'd", 'this', 'be', 'at', 'than', 'herself', 'com', 'otherwise', 'into', 'too', 'here', 'down', 'she', 'ours', "haven't", 'how', "she'll", 'both', 'k', 'to', 'would', 'me', "that's", "isn't", "we've", "where's", 'in', 'against', 'but', 'like', 'more', 'where', 'itself', 'before', 'them', 'those', "hasn't", 'yourselves', 'else', 'for', 'ever', 'after', 'doing', 'hers', "don't", 'why', "we'll", "who's", 'few', 'by', 'could', "it's", "they've", "they'll", 'who', 'during', 'of', 'themselves', 'most', 'that', 'do', 'her', "he'd", "doesn't", 'as', "you're", 'it', 'www', 'him', 'have', 'off', 'r', 'were', "i'll", 'has', 'about', 'what', "couldn't", 'on', 'get', 'until', "how's", 'with', "didn't", 'through', "she'd", 'is', 'myself', "we're", 'below', "can't", 'an', 'because', "wasn't", "what's", 'your', "i've", "aren't", 'when', 'only', "mustn't", 'yourself', 'himself', 'over', 'then', 'or', 'no', "hadn't", 'above', 'all', 'cannot', 'am', 'if', 'and', 'our', 'ourselves', 'same', 'their', "wouldn't", 'my', "let's", 'are', 'they', 'should', 'again', "they're", 'his', 'does', "he'll", "she's", 'these', 'yours', 'had', 'shall', "i'd", 'between', 'you', 'each', "here's", 'he', 'there', 'such', 'just', 'whom', 'can', 'own', 'having', 'its', 'while', "shouldn't", 'very', 'http', 'the', "shan't", 'once', 'any', 'being', 'not', "why's", 'which', "you'd", 'nor', "i'm", 'ought', 'from', 'out', 'under', 'so', 'up', 'however', "he's", 'we', 'been', "weren't", "we'd", 'other', 'also', 'further', 'did', "when's", "you'll", 'theirs', "there's", "you've", 'a', 'i', 'some'}

# %%
from konlpy.tag import Okt   ### Okt
t = Okt()

#from konlpy.tag import Kkma  ### Okt
#t = Kkma()
doc_nouns = t.nouns(text)
print( len( doc_nouns ) )
doc_nouns
# Out:
# 8296
# ['언론사',
#  '코로나',
#  '돈',
#  '미국',
#  '슈퍼',
#  '리치',
#  '자산',
#  '증가',
#  '주식',
#  '거래',
#  '부동산',
#  '보유',
#  '세금',
#  '역대',
#  '최대',
#  '코로나',
#  '슈퍼',
#  '리치',
#  '자산',
#  '베이',
#  '조스',
#  '위',
#  '코로나',
#  '치료',
#  '제',
#  '개발',
#  '뒤',
#  '한국',
#  '코로나',
#  '약',
#  '충격',
#  '맥',
#  '토종',
#  '바이오',
#  '주가',
#  '연일',
#  '급락',
#  '글로벌',
#  '프랜차이즈',
#  '협의',
#  '회',
#  '경기도',
#  '주식회사',
#  '배달',
#  '특급',
#  '활성화',
#  '협약',
#  '고승',
#  '범',
#  '주식',
#  '도세',
#  '문제',
#  '기재부',
#  '협의',
#  '것',
#  '책',
#  '주식',
#  '고수',
#  '말',
#  '로',
#  '연',
#  '수익',
#  '법',
#  '큰손',
#  '최애',
#  '주식',
#  '부터',
#  '루키',
#  '투자',
#  '눈높이',
#  '홍',
#  '장기',
#  '보유',
#  '주식',
#  '세제',
#  '혜택',
#  '자금',
#  '동결',
#  '우려',
#  '악재',
#  '겹겹',
#  '코스피',
#  '건',
#  '위드',
#  '코로나',
#  '차',
#  '백신',
#  '연구소',
#  '코로나',
#  '백신',
#  '안전',
#  '신뢰',
#  '것',
#  '동부',
#  '경남',
#  '김해시',
#  '위드',
#  '코로나',
#  '시대',
#  '새',
#  '관광지',
#  '제작',
#  '혁신',
#  '조달',
#  '노비',
#  '기업',
#  '코로나',
#  '위기',
#  '성장',
#  '률',
#  '큰손',
#  '최애',
#  '주식',
#  '부터',
#  '루키',
#  '투자',
#  '눈높이',
#  '우리',
#  '해외',
#  '주식',
#  '대형',
#  '증권사',
#  '중',
#  '형사',
#  '경제',
#  '주식',
#  '물',
#  '해도',
#  '악재',
#  '체크',
#  '김난도',
#  '위드',
#  '코로나',
#  '시대',
#  '갈림길',
#  '도약',
#  '거나',
#  '위축',
#  '온스',
#  '블러',
#  '썸',
#  '연내',
#  '주식',
#  '거래',
#  '재개',
#  '정상화',
#  '돌입',
#  '국감',
#  '매일',
#  '상당',
#  '사기',
#  '발생',
#  '코로나',
#  '이후',
#  '급증',
#  '코로나',
#  '치료',
#  '제',
#  '개발',
#  '국내',
#  '약주',
#  '직격탄',
#  '국감',
#  '주식',
#  '도세',
#  '과도',
#  '개인',
#  '운동장',
#  '생생',
#  '경제',
#  '코로나',
#  '시대',
#  '업무',
#  '환경',
#  '변화',
#  '비대',
#  '협업툴',
#  '전자',
#  '주식',
#  '매수',
#  '의견',
#  '유지',
#  '고급',
#  '가전',
#  '수요',
#  '코로나',
#  '뒤',
#  '지속',
#  '베트남',
#  '증시',
#  '주식',
#  '계좌',
#  '신규',
#  '개설',
#  '이전',
#  '주식',
#  '채권',
#  '시장',
#  '판단',
#  '스',
#  '태그',
#  '인플레',
#  '채권',
#  '마감',
#  '지옥문',
#  '리다',
#  '코로나',
#  '발발',
#  '이후',
#  '최',
#  '대폭',
#  '급등',
#  '생활',
#  '건강',
#  '주식',
#  '매수',
#  '의견',
#  '유지',
#  '화장품',
#  '브랜드',
#  '가치',
#  '계속',
#  '주식시장',
#  '급락',
#  '가지',
#  '이유',
#  '환율',
#  '유가',
#  '물가',
#  '삼중고',
#  '가중',
#  '코로나',
#  '경제',
#  '회복',
#  '발목',
#  '주식',
#  '확대',
#  '경계',
#  '원자재',
#  '리츠',
#  '은',
#  '축소',
#  '주식',
#  '한국',
#  '비엔',
#  '오전',
#  '장',
#  '급등',
#  '재',
#  '돌파',
#  '역대',
#  '유동성',
#  '증시',
#  '호황',
#  '주식',
#  '가치',
#  '털썩',
#  '투자',
#  '창',
#  '코로나',
#  '주의보',
#  '현재',
#  '진행형',
#  '골드만삭스',
#  '선정',
#  '체제',
#  '속',
#  '급등',
#  '일본',
#  '주식',
#  '선',
#  '국산',
#  '프린터',
#  '개발',
#  '사',
#  '주식회사',
#  '다락방',
#  '크리',
#  '메이커',
#  '메탈',
#  '출시',
#  '로',
#  '쌤',
#  '포인트',
#  '투자',
#  '위드',
#  '코로나',
#  '시대',
#  '뷰티',
#  '꽃',
#  '주',
#  '를',
#  '시립',
#  '수락',
#  '양로원',
#  '코로나',
#  '방역',
#  '마스크',
#  '후원',
#  '코로나',
#  '로',
#  '문',
#  '서산',
#  '베니키아',
#  '호텔',
#  '새',
#  '주인',
#  '재개',
#  '기대',
#  '세대',
#  '코로나',
#  '팬데믹',
#  '동안',
#  '자산',
#  '직장인',
#  '월급',
#  '후',
#  '월급',
#  '고개',
#  '코로나',
#  '장기',
#  '코로나',
#  '발',
#  '제약',
#  '바이오',
#  '지수',
#  '급락',
#  '가치',
#  '입증',
#  '주식회사',
#  '창',
#  '대표이사',
#  '문성호',
#  '농',
#  '축산물',
#  '가격',
#  '안정',
#  '기금',
#  '기탁',
#  '주식',
#  '제주항공',
#  '주가',
#  '상승',
#  '위드',
#  '코로나',
#  '로',
#  '여행',
#  '항',
#  '공주',
#  '미소',
#  '코로나',
#  '장기',
#  '정부',
#  '사칭',
#  '스팸',
#  '급증',
#  '절반',
#  '이상',
#  '불법',
#  '대출',
#  '광고',
#  '변동성',
#  '경기',
#  '회복',
#  '방어',
#  '주',
#  '사라',
#  '해외',
#  '주식',
#  '인',
#  '싸이트',
#  '명품',
#  '대신',
#  '이',
#  '주식',
#  '배',
#  '이익',
#  '돈',
#  '방석',
#  '증시',
#  '둔화',
#  '재테크',
#  '심리',
#  '주식',
#  '부동산',
#  '상승세',
#  '누',
#  '주식',
#  '리츠',
#  '하반기',
#  '주목',
#  '해외',
#  '리츠',
#  '기고',
#  '해외',
#  '취업',
#  '주식',
#  '스톡',
#  '톡스',
#  '선',
#  '붕괴',
#  '신흥',
#  '국',
#  '코로나',
#  '정점',
#  '통과',
#  '여부',
#  '주목',
#  '서학',
#  '개미',
#  '뭐',
#  '위기',
#  '기회',
#  '서학',
#  '개미',
#  '기술',
#  '주',
#  '홍콩',
#  '주식',
#  '러브콜',
#  '상승',
#  '동력',
#  '코스피',
#  '코로나',
#  '이후',
#  '분기',
#  '기준',
#  '첫',
#  '하락',
#  '알약',
#  '코로나',
#  '치료',
#  '제',
#  '뉴욕',
#  '증시',
#  '신',
#  '제약',
#  '주가',
#  '맑음',
#  '김',
#  '총리',
#  '국내',
#  '코로나',
#  '치료',
#  '제',
#  '상황',
#  '검토',
#  '데스크',
#  '칼럼',
#  '코로나',
#  '청구',
#  '주식회사',
#  '투지',
#  '화성시',
#  '자극',
#  '살균제',
#  '후원',
#  '물품',
#  '전달',
#  '은퇴',
#  '시점',
#  '주식',
#  '비중',
#  '이유',
#  '기아',
#  '주식',
#  '매수',
#  '의견',
#  '유지',
#  '우호',
#  '환율',
#  '효과',
#  '생산',
#  '차질',
#  '영향',
#  '방어',
#  '남양유업',
#  '코로나',
#  '악용',
#  '식약처',
#  '대기업',
#  '수수방관',
#  '의혹',
#  '제기',
#  '잠',
#  '못',
#  '주식',
#  '전문가',
#  '스트릿',
#  '우먼',
#  '파이터',
#  '보고',
#  '놀란',
#  '이유',
#  '머크',
#  '코로나',
#  '치료',
#  '제로',
#  '뉴욕증시',
#  '일제',
#  '상승',
#  '오징어',
#  '게임',
#  '최후',
#  '승자',
#  '상금',
#  '주식',
#  '신세계',
#  '위드',
#  '코로나',
#  '로',
#  '소비',
#  '회복',
#  '듯',
#  '대신',
#  '증권',
#  '인플레',
#  '헤지',
#  '수익',
#  '려면',
#  '요지',
#  '부동산',
#  '황금',
#  '반도체',
#  '주식',
#  '사라',
#  '매파',
#  '인사',
#  '두',
#  '명',
#  '낙마',
#  '주식',
#  '거래',
#  '연루',
#  '후',
#  '폭풍',
#  '더벨',
#  '무게',
#  '선진국',
#  '주식',
#  '중심',
#  '포트폴리오',
#  '추천',
#  '부자',
#  '세대',
#  '장외',
#  '주식',
#  '이유',
#  '코로나',
#  '백신',
#  '접종',
#  '초읽기',
#  '혜주',
#  '코로나',
#  '여파',
#  '전기',
#  '료',
#  '고액',
#  '체납',
#  '명',
#  '요금',
#  '주식시장',
#  '와르르',
#  '제약',
#  '바이오',
#  '주',
#  '하루',
#  '새',
#  '총',
#  '증발',
#  '패닉',
#  '중국',
#  '주식',
#  '중학',
#  '개미',
#  '어찌',
#  '리까',
#  '코로나',
#  '휴업',
#  '서산',
#  '베니키아',
#  '호텔',
#  '새',
#  '주인',
#  '주식',
#  '고수',
#  '주식',
#  '사냥',
#  '농사',
#  '주식',
#  '농부',
#  '박영옥',
#  '투자',
#  '관',
#  '여의도',
#  '주식',
#  '강철',
#  '주식',
#  '시스템',
#  '대결',
#  '새',
#  '시즌',
#  '개막',
#  '주식',
#  '반대',
#  '매매',
#  '평균',
#  '연중',
#  '최대',
#  '금감원',
#  '빚투',
#  '폭탄',
#  '경고',
#  '중국',
#  '마이',
#  '종목',
#  '코로나',
#  '치료',
#  '제',
#  '발표',
#  '푸싱',
#  '의약',
#  '주가',
#  '급락',
#  '모건스탠리',
#  '빅딜',
#  '로',
#  '위',
#  '주식',
#  '채권',
#  '발행',
#  '관왕',
#  '주식',
#  '위드',
#  '코로나',
#  '시대',
#  '투자',
#  '전략',
#  '식초',
#  '고수',
#  '지금',
#  '선',
#  '코스피',
#  '한국',
#  '비엔',
#  '저가',
#  '매수',
#  '차',
#  '주식',
#  '현대',
#  '바이오',
#  '주가',
#  '급락',
#  '금융',
#  '돋보기',
#  '주식',
#  '투자',
#  '전략',
#  '현장',
#  '동학',
#  '개미',
#  '주식',
#  '도세',
#  '반대',
#  '이유',
#  '코로나',
#  '용',
#  '치료',
#  '제',
#  '개발',
#  '증시',
#  '게임',
#  '체인',
#  '저',
#  '위드',
#  '코로나',
#  '급',
#  '반등',
#  '기대',
#  '주',
#  '부광약품',
#  '코로나',
#  '치료',
#  '제',
#  '레보',
#  '비르',
#  '효과',
#  '입증',
#  '사실',
#  '개발',
#  '포기',
#  '주식',
#  '주택',
#  '청년',
#  '빚투',
#  '가계부채',
#  '차지',
#  '코로나',
#  '로',
#  '여행사',
#  '생산',
#  '지수',
#  '추락',
#  '인터넷',
#  '쇼핑',
#  '최대',
#  '호황',
#  '서초구',
#  '전국',
#  '최초',
#  '서초',
#  '여성',
#  '일자리',
#  '주식회사',
#  '출범',
#  '셋값',
#  '폭등',
#  '주식',
#  '열풍',
#  '청년',
#  '빚',
#  '크게',
#  '하이트진로',
#  '주식',
#  '매수',
#  '의견',
#  '유지',
#  '거리',
#  '두기',
#  '주류',
#  '업',
#  '황도',
#  '대폭',
#  '회복',
#  '누',
#  '종로',
#  '복판',
#  '서린',
#  '빌딩',
#  '주인',
#  '주식',
#  '대안',
#  '상한',
#  '종목',
#  '혹',
#  '주식',
#  '리딩',
#  '방',
#  '피해',
#  '금',
#  '벌써',
#  '주식시장',
#  '먹구름',
#  '코스피',
#  '개월',
#  '선',
#  '붕괴',
#  '발표',
#  '하루',
#  '전',
#  '주식',
#  '펀드',
#  '준',
#  '넘버',
#  '주식',
#  '빚투',
#  '반대',
#  '매매',
#  '달새',
#  '배',
#  '급증',
#  '연중',
#  '최고',
#  '치',
#  '갱신',
#  '국민',
#  '명',
#  '중',
#  '명',
#  '코로나',
#  '이후',
#  '시간',
#  '증가',
#  '아마존',
#  '코로나',
#  '스포츠',
#  '산업',
#  '열',
#  '살',
#  '주식',
#  '유럽',
#  '밀레',
#  '얼',
#  '성공',
#  '철칙',
#  '끌',
#  '부동산',
#  '주식',
#  '투자',
#  '홍',
#  '최대한',
#  '억제',
#  '종합',
#  '주식시장',
#  '와르르',
#  '제약',
#  '바이오',
#  '주',
#  '하루',
#  '새',
#  '총',
#  '증발',
#  '패닉',
#  '중국',
#  '주식',
#  '중학',
#  '개미',
#  '어찌',
#  '리까',
#  '코로나',
#  '휴업',
#  '서산',
#  '베니키아',
#  '호텔',
#  '새',
#  '주인',
#  '주식',
#  '고수',
#  '주식',
#  '사냥',
#  '농사',
#  '주식',
#  '농부',
#  '박영옥',
#  '투자',
#  '관',
#  '여의도',
#  '주식',
#  '강철',
#  '주식',
#  '시스템',
#  '대결',
#  '새',
#  '시즌',
#  '개막',
#  '코로나',
#  '문',
#  '서산',
#  '베니키아',
#  '호텔',
#  '새',
#  '주인',
#  '주식',
#  '반대',
#  '매매',
#  '평균',
#  '연중',
#  '최대',
#  '금감원',
#  '빚투',
#  '폭탄',
#  '경고',
#  '중국',
#  '마이',
#  '종목',
#  '코로나',
#  '치료',
#  '제',
#  '발표',
#  '푸싱',
#  '의약',
#  '주가',
#  '급락',
#  '모건스탠리',
#  '빅딜',
#  '로',
#  '위',
#  '주식',
#  '채권',
#  '발행',
#  '관왕',
#  '주식',
#  '위드',
#  '코로나',
#  '시대',
#  '투자',
#  '전략',
#  '식초',
#  '고수',
#  '지금',
#  '선',
#  '코스피',
#  '한국',
#  '비엔',
#  '저가',
#  '매수',
#  '차',
#  '주식',
#  '현대',
#  '바이오',
#  '주가',
#  '급락',
#  '금융',
#  '돋보기',
#  '주식',
#  '투자',
#  '전략',
#  '주식',
#  '반대',
#  '매매',
#  '급증',
#  '금감원',
#  '소비자',
#  '경보',
#  '발령',
#  '현장',
#  '동학',
#  '개미',
#  '주식',
#  '도세',
#  '반대',
#  '이유',
#  '코로나',
#  '용',
#  '치료',
#  '제',
#  '개발',
#  '증시',
#  '게임',
#  '체인',
#  '저',
#  '위드',
#  '코로나',
#  '급',
#  '반등',
#  '기대',
#  '주',
#  '부광약품',
#  '코로나',
#  '치료',
#  '제',
#  '레보',
#  '비르',
#  '효과',
#  '입증',
#  '사실',
#  '개발',
#  '포기',
#  '스팸',
#  '코로나',
#  '사람',
#  '불법',
#  '대출',
#  '전화',
#  '스팸',
#  '주식',
#  '주택',
#  '청년',
#  '빚투',
#  '가계부채',
#  '차지',
#  '주식',
#  '주택',
#  '청년',
#  '빚투',
#  '가계부채',
#  '차지',
#  '코로나',
#  '로',
#  '여행사',
#  '생산',
#  '지수',
#  '추락',
#  '인터넷',
#  '쇼핑',
#  '최대',
#  '호황',
#  '코로나',
#  '장기',
#  '악용',
#  '테마주',
#  '불법',
#  '대출',
#  '스팸',
#  '기승',
#  '서초구',
#  '전국',
#  '최초',
#  '서초',
#  '여성',
#  '일자리',
#  '주식회사',
#  '출범',
#  '셋값',
#  '폭등',
#  '주식',
#  '열풍',
#  '청년',
#  '빚',
#  '크게',
#  ...]

# %%
ko = nltk.Text(doc_nouns, name="코로나뉴스_1000")
print(type(ko))
print(len(ko.tokens))
# Out:
# <class 'nltk.text.Text'>
# 8296

# %%
### 단어들의 사용 횟수 확인 - 빈도 분석
type( ko.vocab() ), ko.vocab().most_common(50)
# Out:
# (nltk.probability.FreqDist,
#  [('주식', 468),
#   ('코로나', 380),
#   ('투자', 114),
#   ('주식회사', 83),
#   ('주', 69),
#   ('위드', 67),
#   ('매수', 59),
#   ('해외', 51),
#   ('경기도', 46),
#   ('배', 44),
#   ('치료', 43),
#   ('제', 42),
#   ('증시', 42),
#   ('국내', 40),
#   ('유지', 40),
#   ('주식시장', 40),
#   ('의견', 39),
#   ('백신', 38),
#   ('추석', 37),
#   ('부동산', 35),
#   ('이후', 35),
#   ('개미', 35),
#   ('외국인', 35),
#   ('거래', 34),
#   ('바이오', 33),
#   ('증가', 31),
#   ('시대', 31),
#   ('주가', 29),
#   ('세', 29),
#   ('주목', 28),
#   ('빚투', 28),
#   ('시장', 27),
#   ('금융', 27),
#   ('미국', 25),
#   ('최초', 25),
#   ('개발', 23),
#   ('명', 23),
#   ('종목', 23),
#   ('청년', 23),
#   ('기업', 22),
#   ('지금', 22),
#   ('위', 21),
#   ('로', 21),
#   ('부자', 21),
#   ('중국', 21),
#   ('도입', 21),
#   ('한국', 19),
#   ('고수', 19),
#   ('경제', 19),
#   ('하락', 19)])

# %%
most_fre = ko.vocab().most_common(50)
most_fre
# Out:
# [('주식', 468),
#  ('코로나', 380),
#  ('투자', 114),
#  ('주식회사', 83),
#  ('주', 69),
#  ('위드', 67),
#  ('매수', 59),
#  ('해외', 51),
#  ('경기도', 46),
#  ('배', 44),
#  ('치료', 43),
#  ('제', 42),
#  ('증시', 42),
#  ('국내', 40),
#  ('유지', 40),
#  ('주식시장', 40),
#  ('의견', 39),
#  ('백신', 38),
#  ('추석', 37),
#  ('부동산', 35),
#  ('이후', 35),
#  ('개미', 35),
#  ('외국인', 35),
#  ('거래', 34),
#  ('바이오', 33),
#  ('증가', 31),
#  ('시대', 31),
#  ('주가', 29),
#  ('세', 29),
#  ('주목', 28),
#  ('빚투', 28),
#  ('시장', 27),
#  ('금융', 27),
#  ('미국', 25),
#  ('최초', 25),
#  ('개발', 23),
#  ('명', 23),
#  ('종목', 23),
#  ('청년', 23),
#  ('기업', 22),
#  ('지금', 22),
#  ('위', 21),
#  ('로', 21),
#  ('부자', 21),
#  ('중국', 21),
#  ('도입', 21),
#  ('한국', 19),
#  ('고수', 19),
#  ('경제', 19),
#  ('하락', 19)]

# %%
### 한글에서는 따로 불용어 사전이 없어, 따로 만들거나 또는 파일로 부터 불러올 수 있다.
stop_words = ['진자','명','확','차','제','등','더','속','로','세','률','선','것','주','세','로']

new_ko = [ ]
for one_word in ko:
  if one_word not in stop_words:
    new_ko.append(one_word)

# %%
new_ko = nltk.Text(new_ko, name="코로나_주식_1000_2")

# %%
from wordcloud import WordCloud, STOPWORDS

import numpy as np
from PIL import Image

# %%
data = new_ko.vocab().most_common(1000)

# %%
wc = WordCloud(background_color='white', 
               max_words=200,
               contour_width=3, 
               contour_color="steelblue", 
               font_path=path).generate_from_frequencies(dict(data))

# %%
plt.figure(figsize=(15,8))
plt.imshow(wc)
plt.axis("off")
plt.show()
